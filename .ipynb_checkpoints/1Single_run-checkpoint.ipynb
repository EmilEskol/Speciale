# %%
import os
import openmc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from _Geometry_methods import Geometry_helper as gh
from _Aplha_n_methods import Alpha_N_calc as an
# Reset OpenMC internal IDs to avoid duplicates
openmc.reset_auto_ids()

mat = openmc.Materials.from_xml("materials.xml")

fuel_name = "Fuel_CA_2"

new_geom = True
inner_fuel_r = 35
outer_fuel_r = 75
outer_moderater_r = 80

with_blanket = True
blanket_or = 100

inner_moderator_height = 30

if new_geom:
    geom, mat = gh.set_geom_fuel_shell(inner_fuel_r,outer_fuel_r,outer_moderater_r,with_blanket=with_blanket,
                               blanket_or=blanket_or, fuel_name=fuel_name, materials = mat, inner_moderator_height=inner_moderator_height)
else:
    geom = openmc.Geometry.from_xml("geometry.xml")
# Out:
# Fuel_CA_2
# Fuel_CA_2
# Blanket_CA
# Fuel_A
# Fuel_B
# Fuel_C
# Air
# h2o
# d2o
# uo2

# %%
fuel_material, heavy_water, water, blanket_CA, air, mat = gh.set_mat(fuel_name,materials=mat)
# Out:
# Fuel_CA_2
# Fuel_CA_2
# Blanket_CA
# Fuel_A
# Fuel_B
# Fuel_C
# Air
# h2o
# d2o
# uo2

# %%
#print(cells)
print(fuel_material)
fuel = geom.get_cells_by_name('fuel')[0]
moderator = geom.get_cells_by_name('moderator')[0]
blanket = geom.get_cells_by_name('blanket')[0]
air_cell = geom.get_cells_by_name('air')[0]

inner_fuel_radius = geom.get_surfaces_by_name('fuel_inner')[0].bounding_box('-')[1][0]
outer_fuel_radius = geom.get_surfaces_by_name('fuel_outer')[0].bounding_box('-')[1][0]
outer_radius = geom.get_surfaces_by_name('outer_sphere')[0].bounding_box('-')[1][0]
print(geom.get_surfaces_by_name('outer_sphere')[0].bounding_box('-'))
print(f'fuel radius and outer radius are {inner_fuel_radius}, {outer_fuel_radius} and  {outer_radius}')

cell_colors = {
    fuel: 'red',
    moderator: 'blue',
    air_cell: "lightgrey",
    blanket: 'black'
    }


geom.plot(
    pixels=(400, 400),       # resolution
    basis='xy',              # plane (xy, xz, yz)
    color_by='cell',     # color by material or cell
    colors = cell_colors
    )
# Out:
# Material
# 	ID             =	11
# 	Name           =	Fuel_CA_2
# 	Temperature    =	899.9499999999999
# 	Density        =	4.905 [g/cm3]
# 	Volume         =	707921.1647499999 [cm^3]
# 	Depletable     =	True
# 	S(a,b) Tables
# 	Nuclides
# 	F19            =	0.6441281138790036 [ao]
# 	Li7            =	0.2597864768683274 [ao]
# 	U234           =	4.302802148858144e-05 [ao]
# 	U235           =	0.004813978945337904 [ao]
# 	U238           =	0.09120635195004177 [ao]
# 	U236           =	2.205033580077214e-05 [ao]
#
# BoundingBox(lower_left=(-100.0, -100.0, -100.0), upper_right=(100.0, 100.0, 100.0))
# fuel radius and outer radius are 35.0, 75.0 and  100.0
# <Axes: xlabel='x [cm]', ylabel='y [cm]'>

# %%
#Tallies
resolution_of_mesh=10
mesh_size = int(outer_radius)
os.system("rm tallies.xml")
# Tally 1: energy spectrum in fuel
cell_filter1 = openmc.CellFilter(fuel)
energybins=np.logspace(-2,7,1001) #1000 bins between 1e-2 eV and 1e7 eV
energy_filter = openmc.EnergyFilter(energybins)
    
t1 = openmc.Tally(1)
t1.filters = [cell_filter1,energy_filter]
t1.scores = ['flux']

# Tally 2: Materials flux
# Create mesh which will be used for tally
mesh = openmc.RegularMesh()
mesh.dimension = [mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh]
mesh.lower_left = [-mesh_size, -mesh_size]
mesh.upper_right = [mesh_size, mesh_size]

# Create mesh filter for tally
mesh_filter = openmc.MeshFilter(mesh)

t2 = openmc.Tally(2)
t2.filters = [mesh_filter]
t2.scores = ["flux","fission"] #flux

#implement both tallies
tallies = openmc.Tallies([t1,t2]) #tallies.append(tally) is also an option
print(tallies)
tallies.export_to_xml()
# Out:
# [Tally
# 	ID             =	1
# 	Name           =
# 	Filters        =	CellFilter, EnergyFilter
# 	Nuclides       =
# 	Scores         =	['flux']
# 	Estimator      =	None
# 	Multiply dens. =	True, Tally
# 	ID             =	2
# 	Name           =
# 	Filters        =	MeshFilter
# 	Nuclides       =
# 	Scores         =	['flux', 'fission']
# 	Estimator      =	None
# 	Multiply dens. =	True]

# %%
#Settings
os.system('rm settings.xml')
settings = openmc.Settings()
settings.run_mode = 'eigenvalue'
#point = openmc.stats.Point()


src = source = openmc.IndependentSource(
    space=openmc.stats.Point((0, 0, (outer_fuel_radius+inner_fuel_radius)/2)),
    energy=openmc.stats.Discrete([14e6], [1.0])
    )

neutron_intensities,neutron_energies,total_n_per_s = an.neutron_spectra_from_material(fuel_material,E_min=1e4,nr_points=1000,nr_energies=1000,new_file=False)
neutron_intensities = np.clip(neutron_intensities,0,None)
energy = openmc.stats.Tabular(neutron_energies, neutron_intensities)

fuel_space = openmc.stats.spherical_uniform(r_outer=outer_fuel_radius,r_inner=inner_fuel_radius)

src = openmc.IndependentSource(
    space=fuel_space, energy=energy,
    particle='neutron', strength=total_n_per_s)


#print((0, 0, (outer_fuel_radius+inner_fuel_radius)/2) )
settings.source = src
settings.batches = 100
settings.inactive = 10
settings.particles = 10000
settings.temperature = {
    'method': 'nearest',
    'tolerance': 1000}
# Out:
# rm: cannot remove 'settings.xml': No such file or directory
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# setup done in 0.36644027800139156 s

# %%
os.system('rm s*h5')
os.system('rm p*h5')
  
eigen_model = openmc.Model(geometry=geom, materials=mat, settings=settings, tallies=tallies)
eigen_model.run()
sp = openmc.StatePoint('statepoint.100.h5')
# Out:
# rm: cannot remove 'p*h5': No such file or directory
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-09-14 19:24:42
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for F19
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.98679
#         2/1    0.95227
#         3/1    0.98583
#         4/1    1.01719
#         5/1    0.99203
#         6/1    0.97981
#         7/1    0.95613
#         8/1    1.00290
#         9/1    1.00019
#        10/1    0.97833
#        11/1    0.97188
#        12/1    1.01314    0.99251 +/- 0.02063
#        13/1    0.99792    0.99431 +/- 0.01204
#        14/1    0.98584    0.99220 +/- 0.00878
#        15/1    0.97567    0.98889 +/- 0.00756
#        16/1    0.97797    0.98707 +/- 0.00643
#        17/1    0.98442    0.98669 +/- 0.00545
#        18/1    0.97709    0.98549 +/- 0.00487
#        19/1    0.98245    0.98515 +/- 0.00431
#        20/1    0.99978    0.98662 +/- 0.00412
#        21/1    0.97627    0.98568 +/- 0.00385
#        22/1    0.99603    0.98654 +/- 0.00362
#        23/1    1.00581    0.98802 +/- 0.00364
#        24/1    0.98976    0.98815 +/- 0.00337
#        25/1    0.97380    0.98719 +/- 0.00328
#        26/1    1.00099    0.98805 +/- 0.00319
#        27/1    0.99243    0.98831 +/- 0.00301
#        28/1    0.98263    0.98799 +/- 0.00285
#        29/1    0.97305    0.98721 +/- 0.00281
#        30/1    0.98432    0.98706 +/- 0.00267
#        31/1    0.98319    0.98688 +/- 0.00255
#        32/1    0.98241    0.98668 +/- 0.00244
#        33/1    0.99034    0.98684 +/- 0.00233
#        34/1    0.98000    0.98655 +/- 0.00225
#        35/1    0.99664    0.98695 +/- 0.00220
#        36/1    0.99628    0.98731 +/- 0.00214
#        37/1    0.98095    0.98708 +/- 0.00207
#        38/1    0.98325    0.98694 +/- 0.00200
#        39/1    1.01543    0.98792 +/- 0.00217
#        40/1    0.99518    0.98816 +/- 0.00211
#        41/1    1.02047    0.98921 +/- 0.00229
#        42/1    0.98198    0.98898 +/- 0.00223
#        43/1    0.98241    0.98878 +/- 0.00217
#        44/1    0.99385    0.98893 +/- 0.00211
#        45/1    0.96515    0.98825 +/- 0.00216
#        46/1    0.97785    0.98796 +/- 0.00212
#        47/1    0.97070    0.98750 +/- 0.00211
#        48/1    0.97323    0.98712 +/- 0.00209
#        49/1    0.98786    0.98714 +/- 0.00204
#        50/1    0.98868    0.98718 +/- 0.00198
#        51/1    0.97734    0.98694 +/- 0.00195
#        52/1    0.98950    0.98700 +/- 0.00190
#        53/1    0.99678    0.98723 +/- 0.00187
#        54/1    1.00453    0.98762 +/- 0.00187
#        55/1    0.97919    0.98743 +/- 0.00184
#        56/1    0.98701    0.98742 +/- 0.00180
#        57/1    0.95667    0.98677 +/- 0.00188
#        58/1    0.97698    0.98657 +/- 0.00185
#        59/1    0.98921    0.98662 +/- 0.00181
#        60/1    0.98312    0.98655 +/- 0.00178
#        61/1    0.98359    0.98649 +/- 0.00174
#        62/1    0.98180    0.98640 +/- 0.00171
#        63/1    1.00573    0.98677 +/- 0.00172
#        64/1    0.99729    0.98696 +/- 0.00170
#        65/1    0.97878    0.98681 +/- 0.00167
#        66/1    0.96831    0.98648 +/- 0.00168
#        67/1    0.99166    0.98657 +/- 0.00165
#        68/1    0.98502    0.98655 +/- 0.00162
#        69/1    0.96727    0.98622 +/- 0.00163
#        70/1    0.99267    0.98633 +/- 0.00160
#        71/1    1.00244    0.98659 +/- 0.00160
#        72/1    0.98741    0.98660 +/- 0.00157
#        73/1    0.99626    0.98676 +/- 0.00155
#        74/1    0.99439    0.98688 +/- 0.00153
#        75/1    0.96618    0.98656 +/- 0.00154
#        76/1    0.99258    0.98665 +/- 0.00152
#        77/1    0.99143    0.98672 +/- 0.00150
#        78/1    0.97546    0.98655 +/- 0.00149
#        79/1    1.01500    0.98697 +/- 0.00152
#        80/1    0.97090    0.98674 +/- 0.00152
#        81/1    0.99412    0.98684 +/- 0.00150
#        82/1    0.98097    0.98676 +/- 0.00148
#        83/1    0.98737    0.98677 +/- 0.00146
#        84/1    0.97887    0.98666 +/- 0.00145
#        85/1    0.96601    0.98639 +/- 0.00145
#        86/1    0.98986    0.98643 +/- 0.00143
#        87/1    0.98174    0.98637 +/- 0.00142
#        88/1    0.97447    0.98622 +/- 0.00141
#        89/1    0.98321    0.98618 +/- 0.00139
#        90/1    0.97154    0.98600 +/- 0.00138
#        91/1    0.98290    0.98596 +/- 0.00137
#        92/1    1.00002    0.98613 +/- 0.00136
#        93/1    0.98954    0.98617 +/- 0.00135
#        94/1    0.98614    0.98617 +/- 0.00133
#        95/1    0.99539    0.98628 +/- 0.00132
#        96/1    0.98515    0.98627 +/- 0.00130
#        97/1    0.99225    0.98634 +/- 0.00129
#        98/1    0.99578    0.98644 +/- 0.00128
#        99/1    0.97774    0.98634 +/- 0.00127
#       100/1    0.99700    0.98646 +/- 0.00126
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.3076e-01 seconds
#    Reading cross sections          = 6.1813e-01 seconds
#  Total time in simulation          = 2.0927e+01 seconds
#    Time in transport only          = 1.9844e+01 seconds
#    Time in inactive batches        = 6.1379e-01 seconds
#    Time in active batches          = 2.0314e+01 seconds
#    Time synchronizing fission bank = 7.4063e-02 seconds
#      Sampling source sites         = 6.4001e-02 seconds
#      SEND/RECV source sites        = 8.7254e-03 seconds
#    Time accumulating tallies       = 8.9511e-01 seconds
#    Time writing statepoints        = 4.8713e-02 seconds
#  Total time for finalization       = 1.4042e+00 seconds
#  Total time elapsed                = 2.2987e+01 seconds
#  Calculation Rate (inactive)       = 162922 particles/second
#  Calculation Rate (active)         = 44305.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.98610 +/- 0.00114
#  k-effective (Track-length)  = 0.98646 +/- 0.00126
#  k-effective (Absorption)    = 0.98850 +/- 0.00098
#  Combined k-effective        = 0.98754 +/- 0.00088
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
#print(sp.tallies.keys())
def plotCircle(ax ,r ,mesh_size ,resolution, label=False):
    theta = np.linspace(0, 2*np.pi, 200)
    x = (r * np.cos(theta)+mesh_size)*resolution/2
    y = (r * np.sin(theta)+mesh_size)*resolution/2
    if label:
        ax.plot(x,y,'r--',alpha=0.2,label="edge of fuel shell")
    else:
        ax.plot(x,y,'r--',alpha=0.2)
    return (x,y)

tally = sp.get_tally(id=2)
#print(tally)


flux = tally.get_slice(scores=['flux'])
fission = tally.get_slice(scores=['fission'])

flux.std_dev.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)
flux.mean.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)
fission.std_dev.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)
fission.mean.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)

#Setting up figures using gridspec
fig = plt.figure(figsize=(18,6))
gs = gridspec.GridSpec(1, 3, width_ratios=[1,1,1], wspace=0.4)



ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[1])
ax2 = fig.add_subplot(gs[2])

ax0.set_title("neutron flux\n [particle-cm/source particle]")
im0=ax0.imshow(flux.mean, origin='lower')
plotCircle(ax0, inner_fuel_radius, mesh_size, resolution_of_mesh)
plotCircle(ax0, outer_fuel_radius, mesh_size, resolution_of_mesh, label=True)

ax0.set_xlabel('x [mm]')
ax0.set_ylabel('y [mm]')
fig.colorbar(im0, ax=ax0, fraction=0.046, pad=0.04)
ax0.legend(loc='lower left')

ax1.set_title("fission neutron production\n [particles produced/source particle]")
im1=ax1.imshow(fission.mean, origin='lower')
plotCircle(ax1, inner_fuel_radius, mesh_size, resolution_of_mesh)
plotCircle(ax1, outer_fuel_radius, mesh_size, resolution_of_mesh, label=True)

ax1.set_xlabel('x [mm]')
ax1.set_ylabel('y [mm]')
fig.colorbar(im1, ax=ax1, fraction=0.046, pad=0.04)
ax1.legend(loc='lower left')



# Create log-spaced energy bins from 1 keV to 10 MeV
energy_bins = np.logspace(3,7)

tally1=sp.get_tally(id=1)
#print(tally1.get_pandas_dataframe())

flux1 = tally1.get_pandas_dataframe()


ax2.plot(flux1['energy low [eV]'],flux1['mean'])

# Plot source energy PDF

ax2.set_xscale('log')  # log scale for x-axis
ax2.set_xlabel('Energy (eV)')
ax2.set_ylabel('Flux (particle-cm per source particle)')
ax2.set_title("Neutron energy in fuel")
#ax2.set_title("Neutron energy in moderator")
pos = ax0.get_position()  # returns [left, bottom, width, height]
pos2 = ax2.get_position()
# Set ax2 to have the same vertical position/height
ax2.set_position([pos2.x0, pos.y0, pos.width, pos.height])

# %%
#fig.savefig("Fourth_test_of_moderator_height.svg", format="svg")
