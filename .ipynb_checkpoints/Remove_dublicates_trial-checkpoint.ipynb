# %%
alpha_nuclides=[['U235',0.1],['U235',0.2],['U235',0.3],['U235',0.4],['U238',0.1],['U238',0.11]]



for nuc in alpha_nuclides:
    print(nuc)
    for nuc1 in alpha_nuclides:
        print(nuc1)
        if nuc[0]==nuc1[0] and nuc[1]!=nuc1[1]:
            nuc[1]+=nuc1[1]
            alpha_nuclides.remove(nuc1)
            
print(alpha_nuclides)

print(np.float64(0.012116008667776443)+ 0.000594968850676505+0.0003592623411433209+0.001579613785661903)
# Out:
# ['U235', 0.1]
# ['U235', 0.1]
# ['U235', 0.1]
# ['U235', 0.1]
# ['U235', 0.1]

# %%
from collections import defaultdict

alpha_nuclides=[['U235',0.1],['U235',0.2],['U235',0.3],['U235',0.3],['U238',0.1],['U238',0.11]]
merged = defaultdict(float)

for name, value in alpha_nuclides:
    merged[name] += value

alpha_nuclides = [[name, val] for name, val in merged.items()]
print(alpha_nuclides)
# Out:
# [['U235', 0.9000000000000001], ['U238', 0.21000000000000002]]
