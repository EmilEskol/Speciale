# %%
import openmc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec # makes plot pretty for oneNote
import pandas as pd
import os
import openmc.deplete as dep
import openmc_data_downloader as odd
from PIL import Image
from collections import defaultdict #To use dictionaries to remove dublicates

date = '171225'
number_of_files = -1

# %%
def set_mat(name):
    materials = openmc.Materials.from_xml('materials.xml')
    fuel_mat = None
    water = None
    heavy_water = None
    blanket_CA = None
    for mat in materials:
        print(mat.name)
        if mat.name==name:
            fuel_mat = mat
        elif mat.name=="h2o":
            water = mat
        elif mat.name=="d2o":
            heavy_water = mat
        elif mat.name=="Blanket CA":
            blanket_CA = mat
        
    return fuel_mat, heavy_water, water, blanket_CA
#print(materials)
fuel_material, heavy_water, water, blanket_CA = set_mat("Fuel CA")
print(fuel_material)
print(blanket_CA)
# Out:
# uo2
# h2o
# d2o
# Fuel CA
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Material
# 	ID             =	7
# 	Name           =	Fuel CA
# 	Temperature    =	None
# 	Density        =	43.83576337924426 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	True
# 	S(a,b) Tables
# 	Nuclides
# 	Li6            =	3.6500000000239107e-06 [ao]
# 	Li7            =	0.3649963499999999 [ao]
# 	F19            =	0.5809999999999998 [ao]
# 	U234           =	2.059926688005198e-05 [ao]
# 	U235           =	0.0023046478462013975 [ao]
# 	U238           =	0.043664196492823694 [ao]
# 	U236           =	1.0556394094843727e-05 [ao]
# 	Th230          =	1.6000000000000004e-06 [ao]
# 	Th232          =	0.007998400000000003 [ao]
#
# Material
# 	ID             =	8
# 	Name           =	Blanket CA
# 	Temperature    =	None
# 	Density        =	45.76501020921229 [g/cm3]
# 	Volume         =	None [cm^3]
# 	Depletable     =	True
# 	S(a,b) Tables
# 	Nuclides
# 	Li6            =	0.026561499999999995 [ao]
# 	Li7            =	0.3234384999999999 [ao]
# 	F19            =	0.59         [ao]
# 	Th230          =	1.2000000000000002e-05 [ao]
# 	Th232          =	0.05998800000000002 [ao]

# %%
#Geometry
moderator_cell = None
fuel_cell = None
def set_geom_fuel_shell(water_or,sphere_or,sphere_ir,with_blanket=False,blanket_or=0):
    #
    
    global moderator_cell, fuel_cell
    eps=0.0001 # constant to make sure geomitries dont overlap
    os.system("rm geometry.xml")
    fuel_or = openmc.Sphere(r=sphere_or) #fuel cylinder with outer radius
    fuel_ir = openmc.Sphere(r=sphere_ir) #fuel cylinder with outer radius

    fuel_region = +fuel_ir & -fuel_or      #inside the fuel fuel


    fuel_cell = openmc.Cell(1, 'fuel')

    fuel_cell.fill = fuel_material
    fuel_cell.region = fuel_region

    #Define moderator area
    water_inner_sphere= openmc.Sphere(r=sphere_ir)
    water_middle_sphere= openmc.Sphere(r=sphere_or)
    water_outer_sphere= openmc.Sphere(r=water_or)
    water_region1 = -water_inner_sphere
    water_region2 = +water_middle_sphere & -water_outer_sphere

    moderator_cell = openmc.Cell(3, 'moderator')
    moderator_cell.fill = heavy_water
    moderator_cell.region = water_region1 | water_region2

    
    #If blanket is a part of the geometry
    if with_blanket:
        blanket_outer_sphere = openmc.Sphere(r=blanket_or)
        blanket_region = +water_outer_sphere & -blanket_outer_sphere
        
        blanket_cell = openmc.Cell(4,'blanket')
        blanket_cell.fill = blanket_CA

        boundary = openmc.Sphere(r=blanket_or+eps,boundary_type='reflective')
        outer_cell = openmc.Cell(2,region=+blanket_outer_sphere & -boundary) 
            #Outer_cell is only to sepeate the boundary a bit from the geometry
        root = openmc.Universe(cells=[fuel_cell, moderator_cell,blanket_cell,outer_cell])
    else:
        #we define boundary condition
        boundary = openmc.Sphere(r = water_or+eps, boundary_type='reflective')
        outer_cell = openmc.Cell(2,region = +water_outer_sphere & -boundary)
        root = openmc.Universe(cells=[fuel_cell, moderator_cell,outer_cell])
    
    geom = openmc.Geometry()
    geom.root_universe = root
    geom.export_to_xml()

    return root, fuel_cell, moderator_cell



#main_u = sphere(sphere_r=100) #radius in cm
geom_size=12
geom_or=11
geom_ir=10
main_u,fuel,moderator = set_geom_fuel_shell(water_or=geom_size,sphere_or=geom_or,sphere_ir=geom_ir)

# %%
# Stochastic Volume Calculations
print(fuel_cell)
def stochastic_vol_calc(fuel_cell,geom_or):
    settings_vol = openmc.Settings()
    
    geom = openmc.Geometry.from_xml("geometry.xml")
    mat = openmc.Materials.from_xml("materials.xml")
    vol_model = openmc.Model(geometry=geom, materials=mat, settings=settings_vol)
    
    lower_left = (-geom_or,-geom_or,-geom_or)
    upper_right = (geom_or,geom_or,geom_or)
    fuel_vol_calc = openmc.VolumeCalculation([fuel_cell],int(1e7),lower_left, upper_right) #max # of points 1e8 before slow calc
    
    #Trigger to stop vol_calc if it is precise enough before number of sambling points 
    #makes calculation slow for some reason
    fuel_vol_calc.set_trigger(1e-3, 'rel_err')  
    settings.run_mode = 'volume'
    settings_vol.volume_calculations = [fuel_vol_calc]
    
    vol_model.calculate_volumes()
def shell_vol_calc(geom_or,geom_ir):
    volume=4/3*np.pi*(geom_or**3-geom_ir**3)
    return volume
# Out:
# Cell
# 	ID             =	1
# 	Name           =	fuel
# 	Fill           =	Material 7
# 	Region         =	(2 -1)
# 	Rotation       =	None
# 	Temperature    =	None
# 	Translation    =	None
# 	Volume         =	None

# %%
#Tallies
resolution_of_mesh=10

os.system("rm tallies.xml")
# Tally 1: energy spectrum in fuel
cell_filter1 = openmc.CellFilter(fuel)
energybins=np.logspace(-2,7,1001) #1000 bins between 1e-2 eV and 1e7 eV
energy_filter = openmc.EnergyFilter(energybins)
    
t1 = openmc.Tally(1)
t1.filters = [cell_filter1,energy_filter]
t1.scores = ['flux']

# Tally 2: Materials flux
# Create mesh which will be used for tally
mesh = openmc.RegularMesh()
mesh.dimension = [geom_size*resolution_of_mesh, geom_size*resolution_of_mesh]
mesh.lower_left = [-geom_size, -geom_size]
mesh.upper_right = [geom_size, geom_size]

# Create mesh filter for tally
mesh_filter = openmc.MeshFilter(mesh)

t2 = openmc.Tally(2)
t2.filters = [mesh_filter]
t2.scores = ["flux","fission"] #flux

#implement both tallies
tallies = openmc.Tallies([t1,t2]) #tallies.append(tally) is also an option
print(tallies)
tallies.export_to_xml()
# Out:
# [Tally
# 	ID             =	1
# 	Name           =
# 	Filters        =	CellFilter, EnergyFilter
# 	Nuclides       =
# 	Scores         =	['flux']
# 	Estimator      =	None
# 	Multiply dens. =	True, Tally
# 	ID             =	2
# 	Name           =
# 	Filters        =	MeshFilter
# 	Nuclides       =
# 	Scores         =	['flux', 'fission']
# 	Estimator      =	None
# 	Multiply dens. =	True]

# %%
#Settings
os.system('rm settings.xml')
settings = openmc.Settings()
settings.run_mode = 'eigenvalue'
point = openmc.stats.Point((0, 0, geom_ir+(geom_or-geom_ir)/2))
src = openmc.Source(space=point)


settings.source = src
settings.batches = 100
settings.inactive = 10
settings.particles = 10000
settings.export_to_xml()
# Out:
# /openmc_venv/lib/python3.11/site-packages/openmc/source.py:658: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn("This class is deprecated in favor of 'IndependentSource'", FutureWarning)

# %%
def runOpenmc():
    os.system('rm s*h5')
    os.system('rm p*h5')

    # Reset OpenMC internal IDs to avoid duplicates
    openmc.reset_auto_ids()
    
    geom = openmc.Geometry.from_xml("geometry.xml")
    mat = openmc.Materials.from_xml("materials.xml")
    tallies = openmc.Tallies.from_xml('tallies.xml')
    settings_eigen = openmc.Settings.from_xml('settings.xml')
    eigen_model = openmc.Model(geometry=geom, materials=mat, settings=settings_eigen, tallies=tallies)
    eigen_model.run()
    sp = openmc.StatePoint('statepoint.100.h5')
    return sp.keff

# %%
# Depletion chain (e.g., 'chain_endfb71_u235.xml' or your own)
#chain = dep.Chain.from_xml("chain_endfb71_u235.xml")
def openmcRunDepletion():
    geom = openmc.Geometry.from_xml("geometry.xml")
    mat = openmc.Materials.from_xml("materials.xml")
    chain_file="chain_endfb71_sfr.xml"
    # Depletion operator
    model = openmc.Model(geometry=geom, materials=mat, settings=settings)
    op = dep.CoupledOperator(model,chain_file)
    
    # Initial concentrations
    mats = {uo2.name: uo2}
    
    # Take one timestep
    timestep = [1.0]  # days
    power = 1e6
    #mats = op.evolve(mats, timestep)
    
    # Deplete using mid-point predictor-corrector
    cecm = openmc.deplete.CECMIntegrator(
        op, timestep, power,diff_burnable_mats=True)
    cecm.integrate()
    
    # Now mats[uo2.name] contains new nuclides from fission
    print(mats[uo2.name])

# %%
def runOpenmc_varible_r_shell_model(geom_irs, geom_ors, geom_sizes,with_blanket=False,blanket_ors=None):
    nr_of_fuel_atoms = []
    nr_of_moderator_atoms = []
    keffs = []
    for ir,orad,size,blanket_or in zip(geom_irs,geom_ors,geom_sizes,blanket_ors):
        print(f"ir {ir:.3g}, or {orad:.3g} and geom_size: {size:.3g}, blanket_or: {blanket_or:.3g}")
        #Setting new geometry
        set_geom_fuel_shell(size,orad,ir,with_blanket=with_blanket,blanket_or=blanket_or)
        
        try:
            #runninng openmc in eigenvalue to find keff of geom
            keff=runOpenmc()
            keffs.append(keff)

            #calc volume and nr of atoms
            fuel_cell.volume = shell_vol_calc(orad,ir)
            nr_of_fuel_atoms.append(fuel_cell.atoms['U235'])
            moderator_cell.volume = shell_vol_calc(ir,0) + shell_vol_calc(size,orad)
            nr_of_moderator_atoms.append(moderator_cell.atoms['H2'])
        except Exception as e:
            print(f"Error for,ir: {ir:.2g}, or: {orad:.2g},size: {size:.2g}", e)
            break
            
    return keffs, nr_of_fuel_atoms, nr_of_moderator_atoms

# %%
#Cell for running 
#runOpenmc()

#Setting geometry radius arrays
nr_of_runs = 30
number_of_files += 1
#name = f'ideal_fuel_sphere_{date}_{number_of_files}'
name = f'fuel_sphere_with_blanket_{date}_{number_of_files}'
geom_irs = np.linspace(59.5,59.5,nr_of_runs)
geom_ors = np.linspace(60,60,nr_of_runs)
geom_sizes = np.linspace(60,100,nr_of_runs)
blanket_ors = np.linspace(70,110,nr_of_runs)
with_blanket = False

keffs, nr_of_fuel_atoms, nr_of_moderator_atoms = runOpenmc_varible_r_shell_model(geom_irs, 
                                geom_ors, geom_sizes,with_blanket=with_blanket,blanket_ors=blanket_ors)

#print(keffs)
#print(nr_of_fuel_atoms)
#print(nr_of_moderator_atoms)
keff_values = [keff.nominal_value for keff in keffs]
keff_stds = [keff.std_dev for keff in keffs]

data_to_file = np.column_stack((geom_irs[:len(keff_values)], geom_ors[:len(keff_values)], geom_sizes[:len(keff_values)],
                                keff_values, keff_stds, nr_of_fuel_atoms, nr_of_moderator_atoms))
#Saving data to file
np.savetxt(f'{name}.csv',data_to_file,delimiter=",",
           header='geom_irs, geom_ors, geom_sizes, keff_values, keff_stds, nr_of_fuel_atoms, nr_of_moderator_atoms')
# Out:
# ir 59.5, or 60 and geom_size: 60, blanket_or: 70
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-12-17 08:13:50
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.75298
#         2/1    1.39274
#         3/1    1.41194
#         4/1    1.41022
#         5/1    1.41820
#         6/1    1.38737
#         7/1    1.44793
#         8/1    1.41967
#         9/1    1.43021
#        10/1    1.38113
#        11/1    1.41098
#        12/1    1.40714    1.40906 +/- 0.00192
#        13/1    1.41394    1.41069 +/- 0.00197
#        14/1    1.42518    1.41431 +/- 0.00388
#        15/1    1.42104    1.41566 +/- 0.00329
#        16/1    1.36980    1.40802 +/- 0.00810
#        17/1    1.41893    1.40957 +/- 0.00702
#        18/1    1.42501    1.41150 +/- 0.00638
#        19/1    1.41354    1.41173 +/- 0.00563
#        20/1    1.40078    1.41064 +/- 0.00515
#        21/1    1.42014    1.41150 +/- 0.00474
#        22/1    1.41736    1.41199 +/- 0.00436
#        86/1    1.42093    1.40666 +/- 0.00193
#        87/1    1.41081    1.40671 +/- 0.00191
#        88/1    1.41114    1.40677 +/- 0.00188
#        89/1    1.37962    1.40642 +/- 0.00189
#        90/1    1.42390    1.40664 +/- 0.00188
#        91/1    1.44007    1.40705 +/- 0.00190
#        92/1    1.42216    1.40724 +/- 0.00189
#        93/1    1.40146    1.40717 +/- 0.00187
#        94/1    1.37071    1.40673 +/- 0.00189
#        95/1    1.42301    1.40693 +/- 0.00188
#        96/1    1.40851    1.40694 +/- 0.00186
#        97/1    1.39555    1.40681 +/- 0.00184
#        98/1    1.41794    1.40694 +/- 0.00183
#        99/1    1.40361    1.40690 +/- 0.00181
#       100/1    1.43495    1.40721 +/- 0.00181
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0388e+00 seconds
#    Reading cross sections          = 1.0234e+00 seconds
#  Total time in simulation          = 1.3335e+01 seconds
#    Time in transport only          = 1.3128e+01 seconds
#    Time in inactive batches        = 8.5669e-01 seconds
#    Time in active batches          = 1.2478e+01 seconds
#    Time synchronizing fission bank = 7.2291e-02 seconds
#      Sampling source sites         = 6.3713e-02 seconds
#      SEND/RECV source sites        = 7.4581e-03 seconds
#    Time accumulating tallies       = 8.1946e-02 seconds
#    Time writing statepoints        = 6.3594e-03 seconds
#  Total time for finalization       = 2.3062e-02 seconds
#  Total time elapsed                = 1.4408e+01 seconds
#  Calculation Rate (inactive)       = 116729 particles/second
#  Calculation Rate (active)         = 72127 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.40744 +/- 0.00167
#  k-effective (Track-length)  = 1.40721 +/- 0.00181
#  k-effective (Absorption)    = 1.40768 +/- 0.00112
#  Combined k-effective        = 1.40758 +/- 0.00104
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# ir 59.5, or 60 and geom_size: 61.4, blanket_or: 71.4
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-12-17 08:14:05
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.76118
#         2/1    1.36804
#         3/1    1.37477
#         4/1    1.36518
#         5/1    1.39056
#         6/1    1.40360
#         7/1    1.40679
#         8/1    1.40820
#         9/1    1.39506
#        10/1    1.41837
#        11/1    1.36975
#        12/1    1.37768    1.37371 +/- 0.00396
#        13/1    1.38583    1.37775 +/- 0.00464
#        14/1    1.37911    1.37809 +/- 0.00330
#        78/1    1.38314    1.38722 +/- 0.00202
#        79/1    1.39122    1.38727 +/- 0.00199
#        80/1    1.38527    1.38725 +/- 0.00196
#        81/1    1.36293    1.38690 +/- 0.00196
#        82/1    1.35382    1.38644 +/- 0.00199
#        83/1    1.38028    1.38636 +/- 0.00196
#        84/1    1.37969    1.38627 +/- 0.00194
#        85/1    1.36904    1.38604 +/- 0.00193
#        86/1    1.38949    1.38609 +/- 0.00190
#        87/1    1.41157    1.38642 +/- 0.00191
#        88/1    1.43391    1.38702 +/- 0.00198
#        89/1    1.38073    1.38695 +/- 0.00195
#        90/1    1.37237    1.38676 +/- 0.00194
#        91/1    1.38911    1.38679 +/- 0.00191
#        92/1    1.37729    1.38668 +/- 0.00189
#        93/1    1.38138    1.38661 +/- 0.00187
#        94/1    1.36611    1.38637 +/- 0.00187
#        95/1    1.38708    1.38638 +/- 0.00184
#        96/1    1.37555    1.38625 +/- 0.00183
#        97/1    1.39967    1.38640 +/- 0.00181
#        98/1    1.39270    1.38648 +/- 0.00179
#        99/1    1.38155    1.38642 +/- 0.00177
#       100/1    1.38086    1.38636 +/- 0.00176
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.7855e-01 seconds
#    Reading cross sections          = 9.6659e-01 seconds
#  Total time in simulation          = 1.3614e+01 seconds
#    Time in transport only          = 1.3316e+01 seconds
#    Time in inactive batches        = 8.5470e-01 seconds
#    Time in active batches          = 1.2759e+01 seconds
#    Time synchronizing fission bank = 6.9621e-02 seconds
#      Sampling source sites         = 6.1064e-02 seconds
#      SEND/RECV source sites        = 7.4008e-03 seconds
#    Time accumulating tallies       = 1.6743e-01 seconds
#    Time writing statepoints        = 6.3949e-03 seconds
#  Total time for finalization       = 2.3834e-02 seconds
#  Total time elapsed                = 1.4627e+01 seconds
#  Calculation Rate (inactive)       = 117000 particles/second
#  Calculation Rate (active)         = 70538.9 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.38574 +/- 0.00159
#  k-effective (Track-length)  = 1.38636 +/- 0.00176
#  k-effective (Absorption)    = 1.38843 +/- 0.00106
#  Combined k-effective        = 1.38785 +/- 0.00103
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# ir 59.5, or 60 and geom_size: 62.8, blanket_or: 72.8
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-12-17 08:14:19
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        70/1    1.40776    1.39592 +/- 0.00211
#        71/1    1.39431    1.39589 +/- 0.00207
#        72/1    1.40660    1.39607 +/- 0.00205
#        73/1    1.41767    1.39641 +/- 0.00204
#        74/1    1.38948    1.39630 +/- 0.00201
#        75/1    1.40534    1.39644 +/- 0.00199
#        76/1    1.39543    1.39642 +/- 0.00196
#        77/1    1.37623    1.39612 +/- 0.00195
#        78/1    1.38787    1.39600 +/- 0.00192
#        79/1    1.38157    1.39579 +/- 0.00191
#        80/1    1.39206    1.39574 +/- 0.00188
#        81/1    1.39734    1.39576 +/- 0.00185
#        82/1    1.41093    1.39597 +/- 0.00184
#        83/1    1.35190    1.39537 +/- 0.00191
#        84/1    1.38953    1.39529 +/- 0.00189
#        85/1    1.38915    1.39521 +/- 0.00187
#        86/1    1.41184    1.39543 +/- 0.00185
#        87/1    1.36229    1.39500 +/- 0.00188
#        88/1    1.39360    1.39498 +/- 0.00186
#        89/1    1.37855    1.39477 +/- 0.00184
#        90/1    1.39166    1.39473 +/- 0.00182
#        91/1    1.39179    1.39470 +/- 0.00180
#        92/1    1.38473    1.39457 +/- 0.00178
#        93/1    1.38428    1.39445 +/- 0.00176
#        94/1    1.38665    1.39436 +/- 0.00174
#        95/1    1.38247    1.39422 +/- 0.00173
#        96/1    1.39902    1.39427 +/- 0.00171
#        97/1    1.39249    1.39425 +/- 0.00169
#        98/1    1.38058    1.39410 +/- 0.00168
#        99/1    1.37783    1.39391 +/- 0.00167
#       100/1    1.39683    1.39395 +/- 0.00165
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.6181e-01 seconds
#    Reading cross sections          = 9.5026e-01 seconds
#  Total time in simulation          = 1.2494e+01 seconds
#    Time in transport only          = 1.2307e+01 seconds
#    Time in inactive batches        = 7.9465e-01 seconds
#    Time in active batches          = 1.1699e+01 seconds
#    Time synchronizing fission bank = 6.9924e-02 seconds
#      Sampling source sites         = 6.1224e-02 seconds
#      SEND/RECV source sites        = 7.6056e-03 seconds
#    Time accumulating tallies       = 6.3324e-02 seconds
#    Time writing statepoints        = 6.5363e-03 seconds
#  Total time for finalization       = 2.3010e-02 seconds
#  Total time elapsed                = 1.3490e+01 seconds
#  Calculation Rate (inactive)       = 125841 particles/second
#  Calculation Rate (active)         = 76927.7 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.39505 +/- 0.00149
#  k-effective (Track-length)  = 1.39395 +/- 0.00165
#  k-effective (Absorption)    = 1.39472 +/- 0.00100
#  Combined k-effective        = 1.39457 +/- 0.00095
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# ir 59.5, or 60 and geom_size: 64.1, blanket_or: 74.1
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-12-17 08:14:33
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Re
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.59852 +/- 0.00176
#  k-effective (Track-length)  = 1.59781 +/- 0.00196
#  k-effective (Absorption)    = 1.60129 +/- 0.00087
#  Combined k-effective        = 1.60105 +/- 0.00087
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# ir 59.5, or 60 and geom_size: 100, blanket_or: 110
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-12-17 08:22:26
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=13.
#   warn(msg, IDWarning)
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.75457
#         2/1    1.56787
#         3/1    1.63751
#         4/1    1.58399
#         5/1    1.58074
#         6/1    1.62655
#         7/1    1.58905
#         8/1    1.61100
#         9/1    1.59541
#        10/1    1.60796
#        11/1    1.61726
#        12/1    1.59398    1.60562 +/- 0.01164
#        13/1    1.57109    1.59411 +/- 0.01333
#        14/1    1.58252    1.59121 +/- 0.00986
#        15/1    1.59368    1.59171 +/- 0.00765
#        16/1    1.60321    1.59362 +/- 0.00654
#        17/1    1.61967    1.59734 +/- 0.00666
#        18/1    1.60437    1.59822 +/- 0.00583
#        19/1    1.59067    1.59738 +/- 0.00521
#        20/1    1.52829    1.59047 +/- 0.00834
#        21/1    1.58486    1.58996 +/- 0.00756
#        22/1    1.61088    1.59171 +/- 0.00712
#        23/1    1.59537    1.59199 +/- 0.00655
#        24/1    1.60494    1.59291 +/- 0.00614
#        25/1    1.57375    1.59164 +/- 0.00585
#        26/1    1.58703    1.59135 +/- 0.00548
#        27/1    1.61982    1.59302 +/- 0.00542
#        28/1    1.58917    1.59281 +/- 0.00511
#        29/1    1.62701    1.59461 +/- 0.00516
#        30/1    1.58631    1.59419 +/- 0.00491
#        31/1    1.61824    1.59534 +/- 0.00481
#        32/1    1.59149    1.59516 +/- 0.00459
#        33/1    1.61438    1.59600 +/- 0.00446
#        34/1    1.62222    1.59709 +/- 0.00441
#        35/1    1.62273    1.59812 +/- 0.00435
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0203e+00 seconds
#    Reading cross sections          = 1.0084e+00 seconds
#  Total time in simulation          = 2.8152e+01 seconds
#    Time in transport only          = 2.7855e+01 seconds
#    Time in inactive batches        = 1.7616e+00 seconds
#    Time in active batches          = 2.6391e+01 seconds
#    Time synchronizing fission bank = 6.9015e-02 seconds
#      Sampling source sites         = 6.1082e-02 seconds
#      SEND/RECV source sites        = 6.7916e-03 seconds
#    Time accumulating tallies       = 1.6169e-01 seconds
#    Time writing statepoints        = 6.1595e-03 seconds
#  Total time for finalization       = 2.3215e-02 seconds
#  Total time elapsed                = 2.9207e+01 seconds
#  Calculation Rate (inactive)       = 56767.8 particles/second
#  Calculation Rate (active)         = 34103 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.60005 +/- 0.00178
#  k-effective (Track-length)  = 1.59986 +/- 0.00202
#  k-effective (Absorption)    = 1.59776 +/- 0.00092
#  Combined k-effective        = 1.59786 +/- 0.00094
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
fig_varible_r,axes_varible_r = plt.subplots()
fuel_moderator_ratios = [n/m for n,m in zip(nr_of_fuel_atoms,nr_of_moderator_atoms)]

geom_thickness = [n-m for n,m in zip(geom_ors,geom_irs)]
#print(geom_thickness)
#print(fuel_moderator_ratio)
#print(keff_values)
#keff_errs = [keff.error_value for keff in keffs]

axes_varible_r.plot(fuel_moderator_ratios,keff_values)
#axes_varible_r.plot(geom_thicknes,keff_values)
#axes_varible_r.plot(geom_sizes,keff_values)

axes_varible_r.set_title("Fuel to moderator ratio")

axes_varible_r.set_xlabel("# fuel atoms/# moderator atoms[]")
#axes_varible_r.set_xlabel("# fuel shell thickness[cm]")
#axes_varible_r.set_xlabel("# moderator outer shell radius[cm]")

axes_varible_r.set_ylabel('keff')
axes_varible_r.grid(alpha=0.3)
#axes_varible_r.vlines(0.42,0.8,1.6)

# %%
material_colors = {
    fuel_material: 'red',
    water: 'lightblue',
    heavy_water: 'blue',
    blanket_CA: 'grey'
}

main_u.plot(
    width=(geom_size*2, geom_size*2),        # cm
    pixels=(600, 600),       # resolution
    basis='xy',              # plane (xy, xz, yz)
    color_by='material',     # color by material or cell
    colors = material_colors
)

# %%
# Load the statepoint file
sp = openmc.StatePoint('statepoint.100.h5')
print(sp)
print(sp.tallies.keys())

def plotCircle(ax ,r ,geom_size ,resolution, label=False):
    theta = np.linspace(0, 2*np.pi, 200)
    x = (r * np.cos(theta)+geom_size)*resolution/2
    y = (r * np.sin(theta)+geom_size)*resolution/2
    if label:
        ax.plot(x,y,'r--',alpha=0.2,label="edge of fuel shell")
    else:
        ax.plot(x,y,'r--',alpha=0.2)
    return (x,y)

tally = sp.get_tally(id=2)
print(tally)


flux = tally.get_slice(scores=['flux'])
fission = tally.get_slice(scores=['fission'])

flux.std_dev.shape = (geom_size*resolution_of_mesh, geom_size*resolution_of_mesh)
flux.mean.shape = (geom_size*resolution_of_mesh, geom_size*resolution_of_mesh)
fission.std_dev.shape = (geom_size*resolution_of_mesh, geom_size*resolution_of_mesh)
fission.mean.shape = (geom_size*resolution_of_mesh, geom_size*resolution_of_mesh)

#Setting up figures using gridspec
fig = plt.figure(figsize=(18,6))
gs = gridspec.GridSpec(1, 3, width_ratios=[1,1,1], wspace=0.4)



ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[1])
ax2 = fig.add_subplot(gs[2])

ax0.set_title("neutron flux\n [particle-cm/source particle]")
im0=ax0.imshow(flux.mean)
plotCircle(ax0, geom_ir, geom_size, resolution_of_mesh)
plotCircle(ax0, geom_or, geom_size, resolution_of_mesh, label=True)

ax0.set_xlabel('x [mm]')
ax0.set_ylabel('y [mm]')
fig.colorbar(im0, ax=ax0, fraction=0.046, pad=0.04)
ax0.legend(loc='lower left')

ax1.set_title("fission neutron production\n [particles produced/source particle]")
im1=ax1.imshow(fission.mean)
plotCircle(ax1, geom_ir, geom_size, resolution_of_mesh)
plotCircle(ax1, geom_or, geom_size, resolution_of_mesh, label=True)

ax1.set_xlabel('x [mm]')
ax1.set_ylabel('y [mm]')
fig.colorbar(im1, ax=ax1, fraction=0.046, pad=0.04)
ax1.legend(loc='lower left')



# Create log-spaced energy bins from 1 keV to 10 MeV
energy_bins = np.logspace(3,7)

tally1=sp.get_tally(id=1)
#print(tally1.get_pandas_dataframe())

flux1 = tally1.get_pandas_dataframe()


ax2.plot(flux1['energy low [eV]'],flux1['mean'])

# Plot source energy PDF

ax2.set_xscale('log')  # log scale for x-axis
ax2.set_xlabel('Energy (eV)')
ax2.set_ylabel('Flux (particle-cm per source particle)')
ax2.set_title("Neutron energy in fuel")
#ax2.set_title("Neutron energy in moderator")
pos = ax0.get_position()  # returns [left, bottom, width, height]
pos2 = ax2.get_position()
# Set ax2 to have the same vertical position/height
ax2.set_position([pos2.x0, pos.y0, pos.width, pos.height])

# %%
#Fra chatgpt
# Load depletion results
results = openmc.deplete.Results(filename="depletion_results.h5")

print(results.get_step_where(1.1574074074074073e-05)) #units days
results.export_to_materials(1,path="materials.xml")

# %%
# Load materials from XML
#materials = openmc.Materials.from_xml("materials-finish.xml")

#Using fond materials 
materials = results.export_to_materials(1)
# Collect all nuclides present
nuclides = []

for mat in materials:
    for nuclide, amount,_ in mat.nuclides:
        nuclides.append([nuclide,amount])

print(nuclides)

# %%
import openmc.data
import re
decay = openmc.data.Decay.from_endf("../endf-b-vii.1/decay/dec-094_Pu_239.endf")

def make_AZ_Str(AZ):
    #Makes sure that number has 3 digits as in endf files and turns the numbers into strings
    if AZ < 10:
        AZstr = f"00{AZ}"
    elif AZ < 100:
        AZstr = f"0{AZ}"
    else:
        AZstr = f"{AZ}"
    return AZstr

def has_alpha_decay(nuclide):
    #Checking if atoms have alpha decay
    nuclide_name=nuclide[0]
    Z, A, m =openmc.data.zam(nuclide_name)

    #Isolating the atomic symbol
    #print(nuclide_name)
    match = re.match(r"([A-Za-z]+)(\d+)(_)(m\d+)",nuclide_name)
    #print(match)
    m1=0
    if match == None:
        match = re.match(r"([A-Za-z]+)",nuclide_name)
        symbol =match.groups()[0]
    else:
        symbol, _,_ ,m1 =match.groups()

    #print(symbol,m1)
    Z = make_AZ_Str(Z)
    A = make_AZ_Str(A)
    #print(Z,symbol,A)
    try:
        if m1 != 0:
            dec = openmc.data.Decay.from_endf(f"../endf-b-vii.1/decay/dec-{Z}_{symbol}_{A}{m1}.endf")
        else:
            dec = openmc.data.Decay.from_endf(f"../endf-b-vii.1/decay/dec-{Z}_{symbol}_{A}.endf")
        for mode in dec.modes:
            if mode.modes[0] == "alpha":
                return True
        return False   
    except KeyError:
        print("Error")
        return False

#print(has_alpha_decay(nuclides[3]))        
alpha_nuclides = [nuc for nuc in nuclides if has_alpha_decay(nuc)]

print(alpha_nuclides)

# %%
merged = defaultdict(float)

for name, value in alpha_nuclides:
    merged[name] += value

alpha_nuclides = [[name, val] for name, val in merged.items()]
print(alpha_nuclides)

# %%
def alpha_decay_values(nuclide):
    #Returning possible alpha decay and branching ratios
    nuclide_name=nuclide[0]
    nuclide_amount=nuclide[1]
    Z, A, m =openmc.data.zam(nuclide_name)

    #Isolating the atomic symbol
    #print(nuclide_name)
    match = re.match(r"([A-Za-z]+)(\d+)(_)(m\d+)",nuclide_name)
    #print(match)
    m1=0
    if match == None:
        match = re.match(r"([A-Za-z]+)",nuclide_name)
        symbol =match.groups()[0]
    else:
        symbol, _,_ ,m1 =match.groups()

    #print(symbol,m1)
    Z = make_AZ_Str(Z)
    A = make_AZ_Str(A)
    #print(Z,symbol,A)
    if m1 != 0:
        dec = openmc.data.Decay.from_endf(f"../endf-b-vii.1/decay/dec-{Z}_{symbol}_{A}{m1}.endf")
    else:
        dec = openmc.data.Decay.from_endf(f"../endf-b-vii.1/decay/dec-{Z}_{symbol}_{A}.endf")
    try:
        decay_constant = dec.decay_constant.nominal_value #log(2)/half_life
    except ValueError as e:
        print(f"Skipping {dec.nuclide['name']} amount: {nuclide_amount:.3g}: {e}")
        decay_constant = 0
    if len(dec.spectra)!=0:
        alpha_data=dec.spectra['alpha']
        energies = [float(item['energy'].nominal_value) for item in alpha_data['discrete']] #can be continuous or discrete
        intensities  = [float(item['intensity'].nominal_value) for item in alpha_data['discrete']]
        

        activities = [decay_constant*nuclide_amount*intensity for intensity in intensities] #Calculation of activities
        if sum(activities)>1e-25:
            print(dec.nuclide['name'], f"amount:\t {nuclide_amount:.3g}, \tactivity of most intens line:\t {max(activities):.3g}")
            line, =plt.plot(energies, activities, "_", label=dec.nuclide['name'],ms=10)
            plt.vlines(energies,[0]*len(energies),activities,line.get_color(),alpha=0.3)
        elif sum(activities)>1e-35:
            print(dec.nuclide['name'], f"amount:\t {nuclide_amount:.3g}, \tactivity of most intens line:\t {max(activities):.3g}")
        return [nuclide_name,activities,energies]
    else:
        activity=decay_constant*nuclide_amount
        print(dec.nuclide['name'],"activity: ",f"{activity:.3g}"," has no spectra")
    return None


alpha_nucs_activity=[alpha_decay_values(nuc) for nuc in alpha_nuclides]

alpha_nucs_activity=[nuc for nuc in alpha_nucs_activity if nuc is not None]

plt.title("Alpha spectrum of material of the material with more than 1e-6 ao")
plt.semilogy()
plt.xlabel("energy (eV))")
plt.ylabel("activity (alpha/s)")

plt.legend()
print('\nArray of nuclide and the max activity')
for nuc in alpha_nucs_activity:
    print(nuc[0],max(nuc[1]))
