# %%
from Aplha_n_methods import Alpha_N_calc as an
from Geometry_methods import Geometry_helper as gh

import openmc
import matplotlib.pyplot as plt
# Out:
# Traceback (most recent call last):
#
#   File /openmc_venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3549 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from Aplha_n_methods import Alpha_N_calc as an
#
#   File ~/Speciale/Aplha_n_methods.py:174
#     '''
#     ^
# IndentationError: expected an indented block after function definition on line 173

# %%
#Getting material 
mats = openmc.Materials.from_xml('materials.xml')

# %%
fuel_name= 'Fuel_A'
mat = oh.get_material_by_name(fuel_name,mats)
energies,stopping_powers = an.SR_file_write_and_read(mat)

fig,ax = plt.subplots()
ax.plot(energies,stopping_powers,label=fuel_name)

# %%
#
