# %%
import openmc
import numpy as np
import os
from Geometry_methods import set_geom_fuel_shell, make_settings, set_mat
date = '080126'

# %%
number_of_files = 3
fuel_material, heavy_water, water, blanket_CA, air, mat = set_mat("Fuel CA_2")

def shell_vol_calc(geom_or,geom_ir):
    volume=4/3*np.pi*(geom_or**3-geom_ir**3)
    return volume
# Out:
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2

# %%
def runOpenmc(settings_eigen,geom, mat):
    os.system('rm s*h5')
    os.system('rm p*h5')
    os.system('rm tallies.xml')

    # Reset OpenMC internal IDs to avoid duplicates
    openmc.reset_auto_ids()
    #mat = openmc.Materials.from_xml("materials.xml")
    #tallies = openmc.Tallies.from_xml('tallies.xml')
    eigen_model = openmc.Model(geometry=geom, materials=mat, settings=settings_eigen, tallies = None)
    eigen_model.run()
    sp = openmc.StatePoint('statepoint.100.h5')
    return sp.keff

# %%
def runOpenmc_varible_r_shell_model(inner_fuel_rads, outer_fuel_rads, outer_moderater_rads,
                                    with_blanket=False,blanket_ors=None, inner_moderator_heights=None, materials=None):
    nr_of_fuel_atoms = []
    nr_of_moderator_atoms = []
    keffs = []
    for inner_fuel_rad,outer_fuel_rad,outer_moderater_rad,blanket_or,inner_moderator_height in\
    zip(inner_fuel_rads,outer_fuel_rads,outer_moderater_rads,blanket_ors,inner_moderator_heights):
        print(f"inner_fuel_r {inner_fuel_rad:.3g}, outer_fuel_rad {outer_fuel_rad:.3g}\
        and outer_moderator_r: {outer_moderater_rad:.3g}, blanket_or: {blanket_or:.3g}")
        #Setting new geometry
        geom, mat = set_geom_fuel_shell(inner_fuel_rad,outer_fuel_rad,outer_moderater_rad,with_blanket=with_blanket,
                                   blanket_or=blanket_or, inner_moderator_height=inner_moderator_height, materials=materials)
        
        settings = make_settings(geom)
        try:
            #runninng openmc in eigenvalue to find keff of geom
            keff=runOpenmc(settings,geom, mat)
            keffs.append(keff)

            #calc volume and nr of atoms
            fuel_cell = geom.get_cells_by_name('fuel')[0]
            fuel_cell.volume = shell_vol_calc(outer_fuel_rad,inner_fuel_rad)
            nr_of_fuel_atoms.append(fuel_cell.atoms['U235'])

            moderator_cell = geom.get_cells_by_name('moderator')[0]
            moderator_cell.volume = shell_vol_calc(inner_fuel_rad,0) +\
                shell_vol_calc(outer_moderater_rad,outer_fuel_rad)
            nr_of_moderator_atoms.append(moderator_cell.atoms['H2'])
            
        except Exception as e:
            print(f"Error for: inner_fuel_r {inner_fuel_rad:.3g}, outer_fuel_rad {outer_fuel_rad:.3g}\
                    and outer_moderator_r: {outer_moderater_rad:.3g}, blanket_or: {blanket_or:.3g}", e)
            break
            
    return keffs, nr_of_fuel_atoms, nr_of_moderator_atoms

# %%
#First cell for running  
#runOpenmc()

#Setting geometry radius arrays
nr_of_runs = 25
number_of_files +=1
#name = f'ideal_fuel_sphere_{date}_{number_of_files}'
name = f'fuel_sphere_with_blanket_{date}_{number_of_files}'
inner_fuel_rads      = np.linspace(48,48,nr_of_runs)
outer_fuel_rads      = np.linspace(50,50,nr_of_runs)
outer_moderater_rads = np.linspace(87,87,nr_of_runs)
outer_blanket_rads   = np.linspace(100,100,nr_of_runs)
inner_moderator_heights = np.linspace(0,100,nr_of_runs)
with_blanket = True

print(f'filename: {name}.csv')
keffs, nr_of_fuel_atoms, nr_of_moderator_atoms = runOpenmc_varible_r_shell_model(inner_fuel_rads, 
                                outer_fuel_rads, outer_moderater_rads,with_blanket=with_blanket,
                                blanket_ors=outer_blanket_rads, inner_moderator_heights=inner_moderator_heights, materials=mat,)

#print(keffs)
#print(nr_of_fuel_atoms)
#print(nr_of_moderator_atoms)
keff_values = [keff.nominal_value for keff in keffs]
keff_stds = [keff.std_dev for keff in keffs]

data_to_file = np.column_stack((inner_fuel_rads[:len(keff_values)], outer_fuel_rads[:len(keff_values)], 
                                outer_moderater_rads[:len(keff_values)], outer_blanket_rads[:len(keff_values)],
                                keff_values, keff_stds, nr_of_fuel_atoms, nr_of_moderator_atoms))
#Saving data to file
np.savetxt(f'{name}.csv',data_to_file,delimiter=",",
           header='inner_fuel_rads, outer_fuel_rads, outer_moderater_rads, outer_blanket_rads,keff_values, \
           keff_stds, nr_of_fuel_atoms, nr_of_moderator_atoms')
# Out:
# filename: fuel_sphere_with_blanket_080126_7.csv
# inner_fuel_r 48, outer_fuel_rad 50        and outer_moderator_r: 87, blanket_or: 100
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-01-08 15:54:23
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=5.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=4.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# rm: cannot remove 'tallies.xml': No such file or directory
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading O18 from /root/nndc_hdf5/O18.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Li6
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0
#        70/1    0.65357    0.66308 +/- 0.00135
#        71/1    0.66203    0.66307 +/- 0.00133
#        72/1    0.64679    0.66280 +/- 0.00133
#        73/1    0.67820    0.66305 +/- 0.00133
#        74/1    0.69455    0.66354 +/- 0.00140
#        75/1    0.66465    0.66356 +/- 0.00138
#        76/1    0.66613    0.66360 +/- 0.00136
#        77/1    0.66024    0.66355 +/- 0.00134
#        78/1    0.66099    0.66351 +/- 0.00132
#        79/1    0.65837    0.66343 +/- 0.00130
#        80/1    0.63870    0.66308 +/- 0.00133
#        81/1    0.65907    0.66302 +/- 0.00132
#        82/1    0.66150    0.66300 +/- 0.00130
#        83/1    0.65544    0.66290 +/- 0.00128
#        84/1    0.65200    0.66275 +/- 0.00127
#        85/1    0.64052    0.66246 +/- 0.00129
#        86/1    0.67820    0.66266 +/- 0.00129
#        87/1    0.66430    0.66268 +/- 0.00128
#        88/1    0.66438    0.66271 +/- 0.00126
#        89/1    0.65545    0.66261 +/- 0.00125
#        90/1    0.64653    0.66241 +/- 0.00125
#        91/1    0.66241    0.66241 +/- 0.00123
#        92/1    0.64550    0.66221 +/- 0.00123
#        93/1    0.65079    0.66207 +/- 0.00123
#        94/1    0.66497    0.66210 +/- 0.00121
#        95/1    0.65808    0.66206 +/- 0.00120
#        96/1    0.66229    0.66206 +/- 0.00118
#        97/1    0.64328    0.66184 +/- 0.00119
#        98/1    0.65078    0.66172 +/- 0.00118
#        99/1    0.67177    0.66183 +/- 0.00118
#       100/1    0.67587    0.66199 +/- 0.00117
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.6152e+00 seconds
#    Reading cross sections          = 1.6011e+00 seconds
#  Total time in simulation          = 1.0049e+01 seconds
#    Time in transport only          = 9.9180e+00 seconds
#    Time in inactive batches        = 8.9809e-01 seconds
#    Time in active batches          = 9.1511e+00 seconds
#    Time synchronizing fission bank = 7.1489e-02 seconds
#      Sampling source sites         = 6.0555e-02 seconds
#      SEND/RECV source sites        = 7.2936e-03 seconds
#    Time accumulating tallies       = 6.6330e-05 seconds
#    Time writing statepoints        = 5.0225e-03 seconds
#  Total time for finalization       = 3.6540e-06 seconds
#  Total time elapsed                = 1.1683e+01 seconds
#  Calculation Rate (inactive)       = 111347 particles/second
#  Calculation Rate (active)         = 98348.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.66193 +/- 0.00111
#  k-effective (Track-length)  = 0.66199 +/- 0.00117
#  k-effective (Absorption)    = 0.66127 +/- 0.00104
#  Combined k-effective        = 0.66156 +/- 0.00095
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# inner_fuel_r 48, outer_fuel_rad 50        and outer_moderator_r: 87, blanket_or: 100
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-01-08 15:54:34
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=5.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=4.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# rm: cannot remove 'tallies.xml': No such file or directory
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading O18 from /root/nndc_hdf5/O18.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Li6
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.84295
#         2/1    0.61601
#         3/1    0.64759
#         4/1    0.67934
#         5/1    0.66132
#         6/1    0.67514
#         7/1    0.65766
#         8/1    0.67180
#         9/1    0.66044
#        10/1    0.68291
#        11/1    0.67515
#        12/1    0.66541    0.67028 +/- 0.00487
#        13/1    0.64220    0.66092 +/- 0.00977
#        14/1    0.65733    0.66002 +/- 0.00697
#        15/1    0.65841    0.65970 +/- 0.00541
#        16/1    0.67270    0.66187 +/- 0.00492
#        17/1    0.63273    0.65771 +/- 0.00588
#        18/1    0.67885    0.66035 +/- 0.00574
#        19/1    0.66442    0.66080 +/- 0.00508
#        20/1    0.63759    0.65848 +/- 0.00510
#        21/1    0.65711    0.65835 +/- 0.00462
#        22/1    0.65425    0.65801 +/- 0.00423
#        23/1    0.65702    0.65794 +/- 0.00389
#        24/1    0.65705    0.65787 +/- 0.00360
#        25/1    0.67181    0.65880 +/- 0.00348
#        26/1    0.64194    0.65775 +/- 0.00342
#        27/1    0.65287    0.65746 +/- 0.00323
#        28/1    0.65186    0.65715 +/- 0.00306
#        29/1    0.67950    0.65833 +/- 0.00312
#        30/1    0.65563    0.65819 +/- 0.00297
#        31/1    0.66945    0.65873 +/- 0.00287
#        32/1    0.66938    0.65921 +/- 0.00278
#        33/1    0.69584    0.66080 +/- 0.00310
#        34/1    0.66897    0.66114 +/- 0.00299
#        35/1    0.63713    0.66018 +/- 0.00302
#        36/1    0.67846    0.66089 +/- 0.00299
#        37/1    0.65102    0.66052 +/- 0.00290
#        38/1    0.66010    0.66051 +/- 0.00279
#        39/1    0.65295    0.66025 +/- 0.00271
#        40/1    0.66708    0.66047 +/- 0.00262
#        41/1    0.68492    0.66126 +/- 0.00266
#        42/1    0.66568    0.66140 +/- 0.00258
#        43/1    0.64842    0.66101 +/- 0.00253
#        44/1    0.64620    0.66057 +/- 0.00249
#        45/1    0.62822    0.65965 +/- 0.00259
#        46/1    0.67016    0.65994 +/- 0.00253
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.66211 +/- 0.00119
#  k-effective (Track-length)  = 0.66202 +/- 0.00138
#  k-effective (Absorption)    = 0.66123 +/- 0.00098
#  Combined k-effective        = 0.66154 +/- 0.00094
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# inner_fuel_r 48, outer_fuel_rad 50        and outer_moderator_r: 87, blanket_or: 100
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-01-08 15:54:45
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=5.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=4.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# rm: cannot remove 'tallies.xml': No such file or directory
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading O18 from /root/nndc_hdf5/O18.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Li6
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.84392
#         2/1    0.64085
#         3/1    0.64351
#         4/1    0.67392
#         5/1    0.65147
#         6/1    0.64255
#         7/1    0.64684
#         8/1    0.67782
#         9/1    0.67696
#        10/1    0.65502
#        11/1    0.65577
#        12/1    0.66019    0.65798 +/- 0.00221
#        13/1    0.65654    0.65750 +/- 0.00136
#        14/1    0.65937    0.65797 +/- 0.00107
#        15/1    0.66632    0.65964 +/- 0.00186
#        16/1    0.67589    0.66235 +/- 0.00311
#        17/1    0.66343    0.66250 +/- 0.00263
#        18/1    0.66865    0.66327 +/- 0.00240
#        19/1    0.66427    0.66338 +/- 0.00212
#        20/1    0.66954    0.66400 +/- 0.00200
#        21/1    0.65577    0.66325 +/- 0.00195
#        22/1    0.67794    0.66447 +/- 0.00216
#        23/1    0.64670    0.66311 +/- 0.00241
#        86/1    0.67328    0.66491 +/- 0.00126
#        87/1    0.67562    0.66505 +/- 0.00126
#        88/1    0.68181    0.66527 +/- 0.00126
#        89/1    0.65486    0.66514 +/- 0.00125
#        90/1    0.67890    0.66531 +/- 0.00125
#        91/1    0.65687    0.66520 +/- 0.00123
#        92/1    0.66149    0.66516 +/- 0.00122
#        93/1    0.69210    0.66548 +/- 0.00125
#        94/1    0.67079    0.66555 +/- 0.00123
#        95/1    0.67130    0.66561 +/- 0.00122
#        96/1    0.67812    0.66576 +/- 0.00122
#        97/1    0.66177    0.66571 +/- 0.00120
#        98/1    0.66130    0.66566 +/- 0.00119
#        99/1    0.65119    0.66550 +/- 0.00119
#       100/1    0.67544    0.66561 +/- 0.00118
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3894e+00 seconds
#    Reading cross sections          = 1.3745e+00 seconds
#  Total time in simulation          = 1.0245e+01 seconds
#    Time in transport only          = 1.0119e+01 seconds
#    Time in inactive batches        = 1.0409e+00 seconds
#    Time in active batches          = 9.2040e+00 seconds
#    Time synchronizing fission bank = 7.2719e-02 seconds
#      Sampling source sites         = 6.3731e-02 seconds
#      SEND/RECV source sites        = 7.7241e-03 seconds
#    Time accumulating tallies       = 5.8936e-05 seconds
#    Time writing statepoints        = 3.6740e-03 seconds
#  Total time for finalization       = 3.1160e-06 seconds
#  Total time elapsed                = 1.1647e+01 seconds
#  Calculation Rate (inactive)       = 96072.5 particles/second
#  Calculation Rate (active)         = 97783.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.66573 +/- 0.00106
#  k-effective (Track-length)  = 0.66561 +/- 0.00118
#  k-effective (Absorption)    = 0.66561 +/- 0.00093
#  Combined k-effective        = 0.66563 +/- 0.00085
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# inner_fuel_r 48, outer_fuel_rad 50        and outer_moderator_r: 87, blanket_or: 100
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-01-08 15:54:57
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=5.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=4.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# rm: cannot remove 'tallies.xml': No such file or directory
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading O18 from /root/nndc_hdf5/O18.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Re
#        63/1    0.69177    0.68011 +/- 0.00175
#        64/1    0.68143    0.68014 +/- 0.00172
#        65/1    0.67740    0.68009 +/- 0.00169
#        66/1    0.67104    0.67993 +/- 0.00166
#        67/1    0.66333    0.67964 +/- 0.00166
#        68/1    0.66649    0.67941 +/- 0.00165
#        69/1    0.68369    0.67948 +/- 0.00162
#        70/1    0.66133    0.67918 +/- 0.00162
#        71/1    0.66982    0.67903 +/- 0.00160
#        72/1    0.68079    0.67905 +/- 0.00158
#        73/1    0.67566    0.67900 +/- 0.00155
#        74/1    0.69328    0.67922 +/- 0.00154
#        75/1    0.66092    0.67894 +/- 0.00155
#        76/1    0.68320    0.67901 +/- 0.00152
#        77/1    0.70957    0.67946 +/- 0.00157
#        78/1    0.66962    0.67932 +/- 0.00155
#        79/1    0.66888    0.67917 +/- 0.00154
#        80/1    0.68247    0.67921 +/- 0.00151
#        81/1    0.66588    0.67903 +/- 0.00151
#        82/1    0.69325    0.67922 +/- 0.00150
#        83/1    0.67983    0.67923 +/- 0.00148
#        84/1    0.67212    0.67914 +/- 0.00146
#        85/1    0.67930    0.67914 +/- 0.00144
#        86/1    0.69084    0.67929 +/- 0.00143
#        87/1    0.69405    0.67948 +/- 0.00142
#        88/1    0.68424    0.67954 +/- 0.00141
#        89/1    0.67749    0.67952 +/- 0.00139
#        90/1    0.67935    0.67952 +/- 0.00137
#        91/1    0.67584    0.67947 +/- 0.00136
#        92/1    0.69465    0.67966 +/- 0.00135
#        93/1    0.68272    0.67969 +/- 0.00134
#        94/1    0.68144    0.67971 +/- 0.00132
#        95/1    0.66978    0.67960 +/- 0.00131
#        96/1    0.68528    0.67966 +/- 0.00130
#        97/1    0.67278    0.67958 +/- 0.00128
#        98/1    0.70694    0.67989 +/- 0.00131
#        99/1    0.66509    0.67973 +/- 0.00130
#       100/1    0.67656    0.67969 +/- 0.00129
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4020e+00 seconds
#    Reading cross sections          = 1.3868e+00 seconds
#  Total time in simulation          = 1.0401e+01 seconds
#    Time in transport only          = 1.0261e+01 seconds
#    Time in inactive batches        = 1.0023e+00 seconds
#    Time in active batches          = 9.3986e+00 seconds
#    Time synchronizing fission bank = 8.0559e-02 seconds
#      Sampling source sites         = 6.4116e-02 seconds
#      SEND/RECV source sites        = 8.1912e-03 seconds
#    Time accumulating tallies       = 5.3679e-05 seconds
#    Time writing statepoints        = 4.3997e-03 seconds
#  Total time for finalization       = 3.8200e-06 seconds
#  Total time elapsed                = 1.1816e+01 seconds
#  Calculation Rate (inactive)       = 99769.4 particles/second
#  Calculation Rate (active)         = 95758.5 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.67991 +/- 0.00123
#  k-effective (Track-length)  = 0.67969 +/- 0.00129
#  k-effective (Absorption)    = 0.67965 +/- 0.00105
#  Combined k-effective        = 0.67970 +/- 0.00095
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# inner_fuel_r 48, outer_fuel_rad 50        and outer_moderator_r: 87, blanket_or: 100
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-01-08 15:55:09
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=5.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=4.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# rm: cannot remove 'tallies.xml': No such file or directory
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading O18 from /root/nndc_hdf5/O18.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Li6
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.84535
#         2/1    0.63026
#         3/1    0.64392
#         4/1    0.65379
#         5/1    0.65899
#         6/1    0.65841
#         7/1    0.68034
#         8/1    0.66187
#         9/1    0.68305
#        10/1    0.67784
#        11/1    0.66348
#        12/1    0.65746    0.66047 +/- 0.00301
#        13/1    0.68850    0.66981 +/- 0.00950
#        14/1    0.68556    0.67375 +/- 0.00779
#        15/1    0.69154    0.67731 +/- 0.00700
#        16/1    0.68073    0.67788 +/- 0.00575
#        17/1    0.68626    0.67908 +/- 0.00500
#        18/1    0.68250    0.67950 +/- 0.00435
#        19/1    0.69795    0.68155 +/- 0.00435
#        20/1    0.68517    0.68191 +/- 0.00391
#        21/1    0.69304    0.68293 +/- 0.00368
#        22/1    0.67677    0.68241 +/- 0.00340
#        23/1    0.69820    0.68363 +/- 0.00335
#        24/1    0.70264    0.68499 +/- 0.00339
#        25/1    0.70013    0.68600 +/- 0.00331
#        26/1    0.71319    0.68769 +/- 0.00353
#        27/1    0.67828    0.68714 +/- 0.00336
#        28/1    0.69392    0.68752 +/- 0.00319
#        29/1    0.70322    0.68834 +/- 0.00313
#        30/1    0.70735    0.68929 +/- 0.00312
#        31/1    0.69033    0.68934 +/- 0.00297
#        32/1    0.69755    0.68972 +/- 0.00285
#        33/1    0.70117    0.69022 +/- 0.00277
#        34/1    0.70774    0.69095 +/- 0.00275
#        35/1    0.68442    0.69068 +/- 0.00265
#        36/1    0.71171    0.69149 +/- 0.00267
#        37/1    0.70152    0.69186 +/- 0.00260
#        38/1    0.70332    0.69227 +/- 0.00254
#        39/1    0.72027    0.69324 +/- 0.00263
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4262e+00 seconds
#    Reading cross sections          = 1.4131e+00 seconds
#  Total time in simulation          = 1.0440e+01 seconds
#    Time in transport only          = 1.0302e+01 seconds
#    Time in inactive batches        = 9.8612e-01 seconds
#    Time in active batches          = 9.4542e+00 seconds
#    Time synchronizing fission bank = 7.4306e-02 seconds
#      Sampling source sites         = 6.5175e-02 seconds
#      SEND/RECV source sites        = 7.9556e-03 seconds
#    Time accumulating tallies       = 7.6940e-05 seconds
#    Time writing statepoints        = 5.9662e-03 seconds
#  Total time for finalization       = 3.8950e-06 seconds
#  Total time elapsed                = 1.1883e+01 seconds
#  Calculation Rate (inactive)       = 101408 particles/second
#  Calculation Rate (active)         = 95195.7 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.05169 +/- 0.00141
#  k-effective (Track-length)  = 1.05113 +/- 0.00158
#  k-effective (Absorption)    = 1.05002 +/- 0.00101
#  Combined k-effective        = 1.05037 +/- 0.00100
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# inner_fuel_r 48, outer_fuel_rad 50        and outer_moderator_r: 87, blanket_or: 100
# Fuel CA_1
# Fuel CA_2
# Blanket CA
# Fuel A
# Fuel B
# Fuel C
# Air
# h2o
# d2o
# uo2
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-01-08 15:58:59
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=2.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=5.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=3.
#   warn(msg, IDWarning)
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=4.
#   warn(msg, IDWarning)
# rm: cannot remove 'p*h5': No such file or directory
# rm: cannot remove 'tallies.xml': No such file or directory
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading O18 from /root/nndc_hdf5/O18.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 250 K
#  Maximum neutron data temperature: 2500 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Li6
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.32706
#         2/1    1.03879
#         3/1    1.04608
#         4/1    1.05374
#         5/1    1.06689
#         6/1    1.06398
#         7/1    1.01799
#         8/1    1.03499
#         9/1    1.03649
#        10/1    1.05256
#        11/1    1.06015
#        12/1    1.05543    1.05779 +/- 0.00236
#        13/1    1.04620    1.05393 +/- 0.00410
#        14/1    1.06028    1.05551 +/- 0.00330
#        15/1    1.03880    1.05217 +/- 0.00421
#        16/1    1.07073    1.05527 +/- 0.00463
#        17/1    1.03557    1.05245 +/- 0.00482
#        18/1    1.07133    1.05481 +/- 0.00479
#        19/1    1.00713    1.04951 +/- 0.00678
#        20/1    1.03474    1.04804 +/- 0.00624
#        21/1    1.02202    1.04567 +/- 0.00612
#        84/1    1.08521    1.05112 +/- 0.00198
#        85/1    1.03116    1.05086 +/- 0.00197
#        86/1    1.07448    1.05117 +/- 0.00197
#        87/1    1.07156    1.05143 +/- 0.00196
#        88/1    1.03106    1.05117 +/- 0.00195
#        89/1    1.05902    1.05127 +/- 0.00193
#        90/1    1.05578    1.05133 +/- 0.00191
#        91/1    1.04287    1.05122 +/- 0.00189
#        92/1    1.06353    1.05137 +/- 0.00187
#        93/1    1.05710    1.05144 +/- 0.00185
#        94/1    1.04829    1.05140 +/- 0.00183
#        95/1    1.05539    1.05145 +/- 0.00181
#        96/1    1.06030    1.05155 +/- 0.00179
#        97/1    1.03915    1.05141 +/- 0.00177
#        98/1    1.06394    1.05155 +/- 0.00176
#        99/1    1.04395    1.05147 +/- 0.00174
#       100/1    1.05738    1.05153 +/- 0.00172
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4443e+00 seconds
#    Reading cross sections          = 1.4294e+00 seconds
#  Total time in simulation          = 1.0797e+01 seconds
#    Time in transport only          = 1.0664e+01 seconds
#    Time in inactive batches        = 9.8053e-01 seconds
#    Time in active batches          = 9.8164e+00 seconds
#    Time synchronizing fission bank = 7.4215e-02 seconds
#      Sampling source sites         = 6.4664e-02 seconds
#      SEND/RECV source sites        = 8.1574e-03 seconds
#    Time accumulating tallies       = 6.3330e-05 seconds
#    Time writing statepoints        = 4.2785e-03 seconds
#  Total time for finalization       = 2.8540e-06 seconds
#  Total time elapsed                = 1.2254e+01 seconds
#  Calculation Rate (inactive)       = 101985 particles/second
#  Calculation Rate (active)         = 91683 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.05179 +/- 0.00150
#  k-effective (Track-length)  = 1.05153 +/- 0.00172
#  k-effective (Absorption)    = 1.05249 +/- 0.00109
#  Combined k-effective        = 1.05229 +/- 0.00100
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %%
#Second cell for running 
#runOpenmc()

#Setting geometry radius arrays
number_of_files += 1

name = f'fuel_sphere_with_blanket_{date}_{number_of_files}'
inner_fuel_rads      = np.linspace(8,84,nr_of_runs)
outer_fuel_rads      = np.linspace(10,86,nr_of_runs)
outer_moderater_rads = np.linspace(87,87,nr_of_runs)
outer_blanket_rads   = np.linspace(100,100,nr_of_runs)
with_blanket = True

#keffs, nr_of_fuel_atoms, nr_of_moderator_atoms = runOpenmc_varible_r_shell_model(inner_fuel_rads, 
#                                outer_fuel_rads, outer_moderater_rads,with_blanket=with_blanket,
#                                blanket_ors=outer_blanket_rads)

#print(keffs)
#print(nr_of_fuel_atoms)
#print(nr_of_moderator_atoms)
keff_values = [keff.nominal_value for keff in keffs]
keff_stds = [keff.std_dev for keff in keffs]

data_to_file = np.column_stack((inner_fuel_rads[:len(keff_values)], outer_fuel_rads[:len(keff_values)], 
                                outer_moderater_rads[:len(keff_values)], outer_blanket_rads[:len(keff_values)],
                                keff_values, keff_stds, nr_of_fuel_atoms, nr_of_moderator_atoms))
#Saving data to file
np.savetxt(f'{name}.csv',data_to_file,delimiter=",",
           header='inner_fuel_rads, outer_fuel_rads, outer_moderater_rads, outer_blanket_rads,keff_values, \
           keff_stds, nr_of_fuel_atoms, nr_of_moderator_atoms')
