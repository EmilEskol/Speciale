# %%
import os
import time
import sys
import openmc
import re
import subprocess
from Geometry_methods import get_material_by_name

mats = openmc.Materials.from_xml('materials.xml')

# Shared folder inside the container (must match the -v mount)
shared_folder = "/root/SR_Module"

# Input and output files
input_file = os.path.join(shared_folder, "SR.IN")

# %%
# Step 1: Write input file for SRModule
symbol_to_element_name = {
    "H": "Hydrogen", "He": "Helium", "Li": "Lithium", "Be": "Beryllium",
    "B": "Boron", "C": "Carbon", "N": "Nitrogen", "O": "Oxygen",
    "F": "Fluorine", "Ne": "Neon", "Na": "Sodium", "Mg": "Magnesium",
    "Al": "Aluminum", "Si": "Silicon", "P": "Phosphorus", "S": "Sulfur",
    "Cl": "Chlorine", "Ar": "Argon", "K": "Potassium", "Ca": "Calcium",
    "Sc": "Scandium", "Ti": "Titanium", "V": "Vanadium", "Cr": "Chromium",
    "Mn": "Manganese", "Fe": "Iron", "Co": "Cobalt", "Ni": "Nickel",
    "Cu": "Copper", "Zn": "Zinc", "Ga": "Gallium", "Ge": "Germanium",
    "As": "Arsenic", "Se": "Selenium", "Br": "Bromine", "Kr": "Krypton",
    "Rb": "Rubidium", "Sr": "Strontium", "Y": "Yttrium", "Zr": "Zirconium",
    "Nb": "Niobium", "Mo": "Molybdenum", "Tc": "Technetium", "Ru": "Ruthenium",
    "Rh": "Rhodium", "Pd": "Palladium", "Ag": "Silver", "Cd": "Cadmium",
    "In": "Indium", "Sn": "Tin", "Sb": "Antimony", "Te": "Tellurium",
    "I": "Iodine", "Xe": "Xenon", "Cs": "Cesium", "Ba": "Barium",
    "La": "Lanthanum", "Ce": "Cerium", "Pr": "Praseodymium", "Nd": "Neodymium",
    "Pm": "Promethium", "Sm": "Samarium", "Eu": "Europium", "Gd": "Gadolinium",
    "Tb": "Terbium", "Dy": "Dysprosium", "Ho": "Holmium", "Er": "Erbium",
    "Tm": "Thulium", "Yb": "Ytterbium", "Lu": "Lutetium", "Hf": "Hafnium",
    "Ta": "Tantalum", "W": "Tungsten", "Re": "Rhenium", "Os": "Osmium",
    "Ir": "Iridium", "Pt": "Platinum", "Au": "Gold", "Hg": "Mercury",
    "Tl": "Thallium", "Pb": "Lead", "Bi": "Bismuth", "Po": "Polonium",
    "At": "Astatine", "Rn": "Radon", "Fr": "Francium", "Ra": "Radium",
    "Ac": "Actinium", "Th": "Thorium", "Pa": "Protactinium", "U": "Uranium",
    "Np": "Neptunium", "Pu": "Plutonium", "Am": "Americium", "Cm": "Curium",
    "Bk": "Berkelium", "Cf": "Californium", "Es": "Einsteinium", "Fm": "Fermium",
    "Md": "Mendelevium", "No": "Nobelium", "Lr": "Lawrencium", "Rf": "Rutherfordium",
    "Db": "Dubnium", "Sg": "Seaborgium", "Bh": "Bohrium", "Hs": "Hassium",
    "Mt": "Meitnerium", "Ds": "Darmstadtium", "Rg": "Roentgenium", "Cn": "Copernicium",
    "Nh": "Nihonium", "Fl": "Flerovium", "Mc": "Moscovium", "Lv": "Livermorium",
    "Ts": "Tennessine", "Og": "Oganesson"
}
def make_SR_in (mat,f,E_min=10,E_max=10000,state=0):
    #Method for making txt for .in files used by SR module
    #mat: The material used
    #E_min: minimum energy (keV)
    #E_max: maximumnergy (keV)
    #state: solid=0, gas=1
    empty_string = ''
    
    f.write('---Stopping/Range Input Data (Number-format: Period = Decimal Point)\r\n')
    f.write('---Output File Name\r\n')
    f.write(f'"{mat.name}"\r\n')
    f.write('---Ion(Z), Ion Mass(u)\r\n')
    f.write('2\t4\r\n')  # Helium-4 ion
    f.write('---Target Data: (Solid=0,Gas=1), Density(g/cm3), Compound Corr.\r\n')
    f.write(f'{state}\t {mat.density}\t 0\r\n')  # Note single space after first column
    f.write('---Number of Target Elements\r\n')
    f.write(f'{len(mat.nuclides)}\r\n')
    f.write('---Target Elements: (Z), Target name, Stoich, Target Mass(u)\r\n')
    
    for nuc in mat.nuclides:
        Stoich = nuc[1]
        Z, A, m = openmc.data.zam(nuc[0])
        symbol = re.match('([A-Za-z]+)', nuc[0])[0]
        element_name = symbol_to_element_name[symbol]
        # Match the working spacing exactly:
        # - 3 spaces after Z
        # - element name padded to 15 characters
        # - tab between name and stoich
        # - spaces between stoich and mass number
        f.write(f'{Z:<3}  "{symbol_to_element_name[symbol]}"  {empty_string:<8}\t {Stoich:<25}  {A}\r\n')
    
    f.write('---Output Stopping Units (1-8)\r\n')
    f.write('1\r\n')  # Units eV / Angstrom
    f.write('---Ion Energy : E-Min(keV), E-Max(keV)\r\n')
    f.write(f'{E_min}\t{E_max}')
    f.write(f'\r\n\r\n\r\n\r\n\r\n\r\n')


fuel = get_material_by_name("Fuel_B",mats)
output_file = os.path.join(shared_folder, fuel.name)

with open(input_file, "w",newline="\n") as f:
    make_SR_in(fuel,f)

# %%
# Step 2: Wait for Windows host to run SRModule.exe
print("Waiting for SRModule to produce output...")
#subprocess.run(['/root/SR_Module/SRModule.exe'], check=True)
while not os.path.exists(output_file):
    time.sleep(1)  # check every second
# Out:
# Waiting for SRModule to produce output...

# %%
# Step 3: Read output
with open(output_file, "r") as f:
    results = f.read()

print("SRModule output:")
print(results)
# Out:
# SRModule output:
#  ==================================================================
#               Calculation using SRIM-2006
#               SRIM version ---> SRIM-2012.01
#               Calc. date   ---> april 02, 2026
#  ==================================================================
#
#  Disk File Name = Fuel_B
#
#  Ion = Helium       [2] , Mass = 4 amu
#
#  Density =  2,1545E+00 g/cm3 = 8,8351E+22 atoms/cm3
#  ======= Target  Composition ========
#     Atom   Atom   Atomic    Mass
#     Name   Numb   Percent   Percent
#     ----   ----   -------   -------
#      Li      3    000,00    000,00
#      Li      3    033,40    015,81
#       F      9    056,09    072,66
#      Be      4    009,67    005,94
#      Zr     40    000,41    002,56
#      Zr     40    000,09    000,56
#      Zr     40    000,14    000,85
#      Zr     40    000,14    000,86
#      Zr     40    000,02    000,14
#       U     92    000,00    000,01
#       U     92    000,04    000,57
#       U     92    000,00    000,01
#       U     92    000,00    000,03
#  ====================================
#  Bragg Correction = 0,00%
#  Stopping Units =  eV/Angstrom
#  See bottom of Table for other Stopping units
#
#  Ion = Helium       [2] , Mass = 4 amu
#
#    Ion        dE/dx      dE/dx     Projected  Longitudinal   Lateral
#   Energy      Elec.      Nuclear     Range     Straggling   Straggling
# -----------  ---------- ---------- ----------  ----------  ----------
#   10,00 keV   4,988E+00  1,096E+00    1228 A       563 A       487 A
#   11,00 keV   5,241E+00  1,040E+00    1346 A       598 A       522 A
#  500,00 keV   3,022E+01  6,647E-02    2,41 um     1903 A      2517 A
#  550,00 keV   3,066E+01  6,145E-02    2,57 um     1935 A      2568 A
#  600,00 keV   3,096E+01  5,718E-02    2,73 um     1964 A      2616 A
#  650,00 keV   3,115E+01  5,351E-02    2,89 um     1992 A      2661 A
#  700,00 keV   3,126E+01  5,031E-02    3,05 um     2019 A      2704 A
#  800,00 keV   3,125E+01  4,501E-02    3,37 um     2094 A      2785 A
#  900,00 keV   3,104E+01  4,078E-02    3,69 um     2166 A      2862 A
#    1,00 MeV   3,068E+01  3,732E-02    4,01 um     2235 A      2935 A
#    1,10 MeV   3,023E+01  3,444E-02    4,34 um     2303 A      3005 A
#    1,20 MeV   2,972E+01  3,200E-02    4,67 um     2371 A      3074 A
#    1,30 MeV   2,918E+01  2,990E-02    5,01 um     2438 A      3143 A
#    1,40 MeV   2,861E+01  2,807E-02    5,35 um     2505 A      3210 A
#    1,50 MeV   2,803E+01  2,647E-02    5,70 um     2573 A      3278 A
#    1,60 MeV   2,745E+01  2,505E-02    6,06 um     2642 A      3345 A
#    1,70 MeV   2,687E+01  2,379E-02    6,43 um     2711 A      3413 A
#    1,80 MeV   2,631E+01  2,266E-02    6,81 um     2781 A      3482 A
#    2,00 MeV   2,520E+01  2,070E-02    7,58 um     3025 A      3621 A
#    2,25 MeV   2,390E+01  1,871E-02    8,60 um     3391 A      3800 A
#    2,50 MeV   2,269E+01  1,708E-02    9,67 um     3756 A      3987 A
#    2,75 MeV   2,157E+01  1,573E-02   10,80 um     4122 A      4183 A
#    3,00 MeV   2,055E+01  1,459E-02   11,98 um     4492 A      4387 A
#    3,25 MeV   1,961E+01  1,362E-02   13,22 um     4867 A      4602 A
#    3,50 MeV   1,875E+01  1,277E-02   14,53 um     5247 A      4826 A
#    3,75 MeV   1,796E+01  1,202E-02   15,89 um     5633 A      5061 A
#    4,00 MeV   1,723E+01  1,137E-02   17,31 um     6026 A      5307 A
#    4,50 MeV   1,596E+01  1,026E-02   20,32 um     7463 A      5832 A
#    5,00 MeV   1,486E+01  9,355E-03   23,56 um     8843 A      6400 A
#    5,50 MeV   1,392E+01  8,606E-03   27,03 um     1,02 um     7012 A
#    6,00 MeV   1,311E+01  7,974E-03   30,73 um     1,16 um     7666 A
#    6,50 MeV   1,239E+01  7,433E-03   34,65 um     1,29 um     8363 A
#    7,00 MeV   1,175E+01  6,964E-03   38,79 um     1,43 um     9100 A
#    8,00 MeV   1,068E+01  6,191E-03   47,70 um     1,92 um     1,07 um
#    9,00 MeV   9,817E+00  5,580E-03   57,46 um     2,38 um     1,24 um
#   10,00 MeV   9,021E+00  5,083E-03   68,08 um     2,84 um     1,43 um
# -----------------------------------------------------------
#  Multiply Stopping by        for Stopping Units
#  -------------------        ------------------
#   1,0000E+00                eV/Angstrom
#   1,0000E+01                keV/micron
#   1,0000E+01                MeV/mm
#   4,6416E-02                keV/(ug/cm2)
#   4,6416E-02                MeV/(mg/cm2)
#   4,6416E+01                keV/(mg/cm2)
#   1,1318E+00                 eV/(1E15 atoms/cm2)
#   1,0463E-01                L.S.S. reduced units
#  ==================================================================
#  (C) 1984,1989,1992,1998,2006 by J.P. Biersack and J.F. Ziegler
