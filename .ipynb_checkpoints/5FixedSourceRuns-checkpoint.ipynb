# %%
from _Aplha_n_methods import Alpha_N_calc as an
from _Aplha_n_methods import init_worker
from _Geometry_methods import Geometry_helper as gh
from _Prettyplt import PrettyPlot as pp

import openmc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import os


import openmc.deplete as dep
import time
from collections import defaultdict #To use dictionaries to remove dublicates

# %%
#Setting geometry and materials
#Geometry
new_geom = True
fuel_name="Fuel_CA_2"


if new_geom:
    inner_fuel_r = 35
    outer_fuel_r = 75
    outer_moderater_r = 80
    
    with_blanket = True
    blanket_or = 100
    
    inner_moderator_height = 25
    geom, materials= gh.set_geom_fuel_shell(inner_fuel_r,outer_fuel_r,outer_moderater_r,with_blanket=with_blanket,
                               blanket_or=blanket_or, inner_moderator_height=inner_moderator_height, fuel_name=fuel_name)
else:
    openmc.reset_auto_ids()
    geom = openmc.Geometry.from_xml("geometry.xml")
    materials= openmc.Materials.from_xml('materials.xml')
fuel = gh.get_material_by_name(fuel_name,materials)
# Out:
# Fuel_CA_1
# Fuel_CA_2
# Blanket_CA
# Fuel_A
# Fuel_B
# Fuel_C
# Air
# h2o
# d2o
# uo2

# %%
neutron_intensities,neutron_energies,n_per_s_per_kg = an.neutron_spectra_from_material(fuel,E_min=1e4,nr_points=1000,nr_energies=1000,new_file=False)
neutron_intensities = np.clip(neutron_intensities,0,None)
energy = openmc.stats.Tabular(neutron_energies, neutron_intensities)

fig,ax =plt.subplots()

ax.plot(neutron_energies,neutron_intensities)

print(n_per_s_per_kg)
# Out:
# /openmc_venv/lib/python3.11/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
# setup done in 0.3307477369962726 s
# 153.51937278327304

# %%
def shell_vol_calc(geom_or,geom_ir):
    volume=4/3*np.pi*(geom_or**3-geom_ir**3)
    return volume

fuel_vol = shell_vol_calc(outer_fuel_r,inner_fuel_r)
fuel_mass = fuel.density*fuel_vol/1000 #g/cm^3*cm^3 -> kg

fuel.volume = fuel_vol

print('fuel_mass',fuel_mass)

total_n_per_s = n_per_s_per_kg*fuel_mass

print('total n production',total_n_per_s)
# Out:
# fuel_mass 7786.940046746876
# total n production 1195446.1518775313

# %%
#Setting source and settings
inner_fuel_radius = geom.get_surfaces_by_name('fuel_inner')[0].bounding_box('-')[1][0]
outer_fuel_radius = geom.get_surfaces_by_name('fuel_outer')[0].bounding_box('-')[1][0]

fuel_space = openmc.stats.spherical_uniform(r_outer=outer_fuel_radius,r_inner=inner_fuel_radius)

src = openmc.IndependentSource(
    space=fuel_space, energy=energy,
    particle='neutron', strength=total_n_per_s)

settings = openmc.Settings()
settings.run_mode = 'eigenvalue'
settings.source = [src]   # evt. + SF-kilde som separat source
settings.batches = 50
settings.inactive = 10
settings.particles = 10000 # is changed later

#Fixing Li6 at 900 K doesn't have a cross section 
settings.temperature = {
    'method': 'nearest',
    'tolerance': 1000}

model_eigen = openmc.Model(geometry=geom, materials=materials, settings=settings)

model_eigen.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-09-15 13:44:30
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for F19
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.97095
#         2/1    0.96197
#         3/1    0.96919
#         4/1    0.98864
#         5/1    1.00206
#         6/1    0.98069
#         7/1    0.97409
#         8/1    0.97803
#         9/1    0.98483
#        10/1    0.96652
#        11/1    0.98085
#        12/1    0.98646    0.98365 +/- 0.00281
#        13/1    1.00298    0.99009 +/- 0.00664
#        14/1    0.97423    0.98613 +/- 0.00615
#        15/1    0.99527    0.98796 +/- 0.00510
#        16/1    1.01502    0.99247 +/- 0.00614
#        17/1    0.97148    0.98947 +/- 0.00599
#        18/1    0.98806    0.98929 +/- 0.00519
#        19/1    0.98150    0.98843 +/- 0.00466
#        20/1    0.98699    0.98828 +/- 0.00417
#        21/1    0.99177    0.98860 +/- 0.00379
#        22/1    0.98534    0.98833 +/- 0.00347
#        23/1    1.01170    0.99013 +/- 0.00366
#        24/1    1.00312    0.99105 +/- 0.00351
#        25/1    1.00401    0.99192 +/- 0.00338
#        26/1    1.00584    0.99279 +/- 0.00328
#        27/1    0.99897    0.99315 +/- 0.00310
#        28/1    1.00320    0.99371 +/- 0.00298
#        29/1    0.96365    0.99213 +/- 0.00323
#        30/1    0.99382    0.99221 +/- 0.00307
#        31/1    0.99212    0.99221 +/- 0.00292
#        32/1    0.98601    0.99193 +/- 0.00280
#        33/1    0.98266    0.99152 +/- 0.00270
#        34/1    0.97682    0.99091 +/- 0.00266
#        35/1    1.00136    0.99133 +/- 0.00258
#        36/1    1.00568    0.99188 +/- 0.00254
#        37/1    0.99269    0.99191 +/- 0.00245
#        38/1    0.99207    0.99192 +/- 0.00236
#        39/1    0.97868    0.99146 +/- 0.00232
#        40/1    0.99927    0.99172 +/- 0.00226
#        41/1    0.98781    0.99159 +/- 0.00219
#        42/1    0.97688    0.99113 +/- 0.00217
#        43/1    1.00550    0.99157 +/- 0.00214
#        44/1    0.99999    0.99182 +/- 0.00210
#        45/1    1.00234    0.99212 +/- 0.00206
#        46/1    0.99819    0.99229 +/- 0.00201
#        47/1    0.95871    0.99138 +/- 0.00215
#        48/1    0.98626    0.99124 +/- 0.00210
#        49/1    0.97232    0.99076 +/- 0.00210
#        50/1    0.97896    0.99046 +/- 0.00207
#  Creating state point statepoint.50.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3444e+00 seconds
#    Reading cross sections          = 1.3100e+00 seconds
#  Total time in simulation          = 4.1029e+00 seconds
#    Time in transport only          = 3.9919e+00 seconds
#    Time in inactive batches        = 7.8327e-01 seconds
#    Time in active batches          = 3.3196e+00 seconds
#    Time synchronizing fission bank = 5.6947e-02 seconds
#      Sampling source sites         = 4.7984e-02 seconds
#      SEND/RECV source sites        = 7.9318e-03 seconds
#    Time accumulating tallies       = 3.9263e-05 seconds
#    Time writing statepoints        = 1.7114e-02 seconds
#  Total time for finalization       = 1.8230e-05 seconds
#  Total time elapsed                = 5.4621e+00 seconds
#  Calculation Rate (inactive)       = 127670 particles/second
#  Calculation Rate (active)         = 120496 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.98948 +/- 0.00171
#  k-effective (Track-length)  = 0.99046 +/- 0.00207
#  k-effective (Absorption)    = 0.98706 +/- 0.00145
#  Combined k-effective        = 0.98790 +/- 0.00133
#  Leakage Fraction            = 0.00000 +/- 0.00000
# PosixPath('/root/Speciale/statepoint.50.h5')

# %%
settings.run_mode = 'fixed source'
settings.batches = 20
settings.inactive = 5
settings.particles = 5000 

#Tallies
resolution_of_mesh=10
mesh_size = int(blanket_or)
os.system("rm tallies.xml")
# Tally 1: energy spectrum in fuel

fuel_cell = geom.get_cells_by_name('fuel')[0]
cell_filter1 = openmc.CellFilter(fuel_cell)
energybins=np.logspace(-2,7,1001) #1000 bins between 1e-2 eV and 1e7 eV
energy_filter = openmc.EnergyFilter(energybins)
    
t1 = openmc.Tally(1)
t1.filters = [cell_filter1,energy_filter]
t1.scores = ['flux']

# Tally 2: Materials flux
# Create mesh which will be used for tally
mesh = openmc.RegularMesh()
mesh.dimension = [mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh]
mesh.lower_left = [-mesh_size, -mesh_size]
mesh.upper_right = [mesh_size, mesh_size]

# Create mesh filter for tally
mesh_filter = openmc.MeshFilter(mesh)

t2 = openmc.Tally(2)
t2.filters = [mesh_filter]
t2.scores = ["flux","fission"] #flux

#implement both tallies
tallies = openmc.Tallies([t1,t2]) #tallies.append(tally) is also an option
print(tallies)
tallies.export_to_xml()

model_fixed = openmc.Model(geometry=geom, materials=materials, settings=settings,tallies=tallies)
model_fixed.run()
# Out:
# [Tally
# 	ID             =	1
# 	Name           =
# 	Filters        =	CellFilter, EnergyFilter
# 	Nuclides       =
# 	Scores         =	['flux']
# 	Estimator      =	None
# 	Multiply dens. =	True, Tally
# 	ID             =	2
# 	Name           =
# 	Filters        =	MeshFilter
# 	Nuclides       =
# 	Scores         =	['flux', 'fission']
# 	Estimator      =	None
# 	Multiply dens. =	True]
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2026-09-15 13:44:37
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file 'model.xml' ...
#  WARNING: Other XML file input(s) are present. These files may be ignored in
#           favor of the model.xml file.
#  Reading cross sections XML file...
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading Li7 from /root/nndc_hdf5/Li7.h5
#  Reading U234 from /root/nndc_hdf5/U234.h5
#  Reading U235 from /root/nndc_hdf5/U235.h5
#  Reading U238 from /root/nndc_hdf5/U238.h5
#  Reading U236 from /root/nndc_hdf5/U236.h5
#  Reading Th230 from /root/nndc_hdf5/Th230.h5
#  Reading Th232 from /root/nndc_hdf5/Th232.h5
#  Reading Li6 from /root/nndc_hdf5/Li6.h5
#  Reading Be9 from /root/nndc_hdf5/Be9.h5
#  Reading Zr90 from /root/nndc_hdf5/Zr90.h5
#  Reading Zr91 from /root/nndc_hdf5/Zr91.h5
#  Reading Zr92 from /root/nndc_hdf5/Zr92.h5
#  Reading Zr94 from /root/nndc_hdf5/Zr94.h5
#  Reading Zr96 from /root/nndc_hdf5/Zr96.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_H_in_H2O from /root/nndc_hdf5/c_H_in_H2O.h5
#  Reading c_D_in_D2O from /root/nndc_hdf5/c_D_in_D2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for F19
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Simulating batch 11
#  Simulating batch 12
#  Simulating batch 13
#  Simulating batch 14
#  Simulating batch 15
#  Simulating batch 16
#  Simulating batch 17
#  Simulating batch 18
#  Simulating batch 19
#  Simulating batch 20
#  Creating state point statepoint.20.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.4555e-01 seconds
#    Reading cross sections          = 7.2776e-01 seconds
#  Total time in simulation          = 2.5025e+02 seconds
#    Time in transport only          = 2.5002e+02 seconds
#    Time in active batches          = 2.5025e+02 seconds
#    Time accumulating tallies       = 1.4649e-01 seconds
#    Time writing statepoints        = 6.6392e-02 seconds
#  Total time for finalization       = 1.5052e+00 seconds
#  Total time elapsed                = 2.5252e+02 seconds
#  Calculation Rate (active)         = 399.607 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.00000 +/- 0.00000
# PosixPath('/root/Speciale/statepoint.20.h5')

# %%
#print(sp.tallies.keys())
def plotCircle(ax ,r ,mesh_size ,resolution, label=False):
    theta = np.linspace(0, 2*np.pi, 200)
    x = (r * np.cos(theta)+mesh_size)*resolution/2
    y = (r * np.sin(theta)+mesh_size)*resolution/2
    if label:
        ax.plot(x,y,'r--',alpha=0.2,label="edge of fuel shell")
    else:
        ax.plot(x,y,'r--',alpha=0.2)
    return (x,y)

sp = openmc.StatePoint(f'statepoint.{settings.batches}.h5')
tally = sp.get_tally(id=2)
#print(tally)


flux = tally.get_slice(scores=['flux'])
fission = tally.get_slice(scores=['fission'])

flux.std_dev.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)
flux.mean.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)
fission.std_dev.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)
fission.mean.shape = (mesh_size*resolution_of_mesh, mesh_size*resolution_of_mesh)

#Setting up figures using gridspec
fig = plt.figure(figsize=(18,6))
gs = gridspec.GridSpec(1, 3, width_ratios=[1,1,1], wspace=0.4)



ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[1])
ax2 = fig.add_subplot(gs[2])

ax0.set_title("neutron flux\n [particle-cm/source particle]")
im0=ax0.imshow(flux.mean, origin='lower')
plotCircle(ax0, inner_fuel_radius, mesh_size, resolution_of_mesh)
plotCircle(ax0, outer_fuel_radius, mesh_size, resolution_of_mesh, label=True)

ax0.set_xlabel('x [mm]')
ax0.set_ylabel('y [mm]')
fig.colorbar(im0, ax=ax0, fraction=0.046, pad=0.04)
ax0.legend(loc='lower left')

ax1.set_title("fission neutron production\n [particles produced/source particle]")
im1=ax1.imshow(fission.mean, origin='lower')
plotCircle(ax1, inner_fuel_radius, mesh_size, resolution_of_mesh)
plotCircle(ax1, outer_fuel_radius, mesh_size, resolution_of_mesh, label=True)

ax1.set_xlabel('x [mm]')
ax1.set_ylabel('y [mm]')
fig.colorbar(im1, ax=ax1, fraction=0.046, pad=0.04)
ax1.legend(loc='lower left')



# Create log-spaced energy bins from 1 keV to 10 MeV
energy_bins = np.logspace(3,7)

tally1=sp.get_tally(id=1)
#print(tally1.get_pandas_dataframe())

flux1 = tally1.get_pandas_dataframe()


ax2.plot(flux1['energy low [eV]'],flux1['mean'])

# Plot source energy PDF

ax2.set_xscale('log')  # log scale for x-axis
ax2.set_xlabel('Energy (eV)')
ax2.set_ylabel('Flux (particle-cm per source particle)')
ax2.set_title("Neutron energy in fuel")
#ax2.set_title("Neutron energy in moderator")
pos = ax0.get_position()  # returns [left, bottom, width, height]
pos2 = ax2.get_position()
# Set ax2 to have the same vertical position/height
ax2.set_position([pos2.x0, pos.y0, pos.width, pos.height])
